# %% [markdown]
# ## The N Queens Problem
# * Given an integer n, the task is to find the solution to the n-queens problem, where n queens are placed on an n*n chessboard such that no two queens can attack each other.
#
# * The N Queen is the problem of placing N chess queens on an N×N chessboard so that no two queens attack each other.
#
# * 參考自 **GeeksforGeeks** : https://www.geeksforgeeks.org/n-queen-problem-backtracking-3/

# %% [markdown]
# ## 前言
# * N Queen Problem 對於放置 N 個 Queen 使其不衝突，由教授 Tronclass 的說明，可以從每個 row 開始下手，因為一但某個 row 的隨便一個 column 放下了皇后，那麼該 row 便無法再放下任何皇后，同理，我們也可以從 column 開始下手。
# * 此作業其實是 8 Queen Problem，但是之前我自己是有在 LeetCode 上面解到兩題跟 N Queen Problem 有直接關聯性的問題，因此才提到 N Queen Problem。LeetCode 相關問題網址：
#     - N-Queens : https://leetcode.com/problems/n-queens/
#     - N-Queens II : https://leetcode.com/problems/n-queens-ii/
# * 並在下方附上我對於 N-Queens 的解答，至於 N-Queens II 其實就只是回傳 N-Queens 該題的答案的長度即可。
# * Note：
#     - 由於原先是使用 C++ 撰寫，後來就單純透過 python3 來改寫以達到類似 C++ 風格的程式碼。
#     - 至於此 Lab 要求的 8 Queen，可直接輸入 n = 8 即可。

# %%
import os
from typing import *    # for python3

class Solution:
    def __init__(self):
        self.queen_move_directions: List[Tuple[int, int]] = [
            (1, 0),    # right
            (1, 1),    # right down
            (0, 1),    # down
            (-1, 1),   # left down
            (-1, 0),   # left
            (-1, -1),  # left top
            (0, -1),   # top
            (1, -1),   # right top
        ]
        self.result: List[List[str]] = []
        self.chess_board_size: int = 0
        self.output_dir = './outputs/'

    def is_valid_position(self, i: int, j: int) -> bool:
        return 0 <= i < self.chess_board_size and 0 <= j < self.chess_board_size

    def flip_positions(self, i: int, j: int, is_available: bool, block_count: List[List[int]]) -> None:
        for d_i, d_j in self.queen_move_directions:
            current_row, current_col = i, j
            while self.is_valid_position(current_row, current_col):
                block_count[current_row][current_col] = max(0, block_count[current_row][current_col] + (-1 if is_available else 1))
                current_row += d_i
                current_col += d_j

    def backtrack(self, current_row: int, current_board: List[str], block_count: List[List[int]]) -> None:
        if current_row == self.chess_board_size:
            self.result.append(["".join(row) for row in current_board])
            return

        for col in range(self.chess_board_size):
            if block_count[current_row][col] == 0:
                self.flip_positions(current_row, col, False, block_count)
                current_board[current_row][col] = 'Q'
                self.backtrack(current_row + 1, current_board, block_count)
                current_board[current_row][col] = '.'
                self.flip_positions(current_row, col, True, block_count)

    def solveNQueens(self, n: int) -> List[List[str]]:
        self.chess_board_size = n
        board = [['.'] * n for _ in range(n)]
        block_count = [[0] * n for _ in range(n)]
        self.backtrack(0, board, block_count)
        return self.result  # 改成 return len(self.result) 即可完成 N-Queens II 的問題
    
    def print_result(self) -> None:
        if not self.result:
            print(f"No solution for {self.chess_board_size} Queens Problem.\n")
            return

        print(f"================================= {self.chess_board_size} Queens Problem Result =================================")
        for i in range(len(self.result)):
            print(f"{i}th {self.chess_board_size} Queens Problem Result:")
            for row in self.result[i]:
                print(row)
            print()
        print(f"================================= {self.chess_board_size} Queens Problem Result =================================")

    def write_result_to_file(self, file_name: str = "output.txt") -> None:
        # 新增這一行，確保資料夾存在
        os.makedirs(self.output_dir, exist_ok=True)
        with open(self.output_dir + f"{file_name}.txt", "a", encoding="utf-8") as f:
            f.write(f"================================= {self.chess_board_size} Queens Problem Result =================================")
            if not self.result:
                f.write(f"No solution for {self.chess_board_size} Queens Problem.\n\n")
                return
            for i in range(len(self.result)):
                f.write(f"{i}th {self.chess_board_size} Queens Problem Result: \n")
                for row in self.result[i]:
                    f.write(row + "\n")
                f.write("\n")
            f.write(f"================================= {self.chess_board_size} Queens Problem Result =================================")

# %%
for n in range(1, 10):
    print(f"================================= {n} Queens Problem Result =================================")
    solution = Solution()
    result = solution.solveNQueens(n)
    solution.print_result()
    print(f"================================= {n} Queens Problem Result =================================", end='\n\n')
# Out:
# ================================= 1 Queens Problem Result =================================
# ================================= 1 Queens Problem Result =================================
# 0th 1 Queens Problem Result:
# Q
#
# ================================= 1 Queens Problem Result =================================
# ================================= 1 Queens Problem Result =================================
#
# ================================= 2 Queens Problem Result =================================
# No solution for 2 Queens Problem.
#
# ================================= 2 Queens Problem Result =================================
#
# ================================= 3 Queens Problem Result =================================
# No solution for 3 Queens Problem.
#
# ================================= 3 Queens Problem Result =================================
#
# ================================= 4 Queens Problem Result =================================
# ================================= 4 Queens Problem Result =================================
# 0th 4 Queens Problem Result:
# .Q..
# ...Q
# Q...
# ..Q.
#
# 1th 4 Queens Problem Result:
# ..Q.
# Q...
# ...Q
# .Q..
#
# ================================= 4 Queens Problem Result =================================
# ================================= 4 Queens Problem Result =================================
#
# ================================= 5 Queens Problem Result =================================
# ================================= 5 Queens Problem Result =================================
# 0th 5 Queens Problem Result:
# Q....
# ..Q..
# ....Q
# .Q...
# ...Q.
#
# 1th 5 Queens Problem Result:
# Q....
# ...Q.
# .Q...
# ....Q
# ..Q..
#
# 2th 5 Queens Problem Result:
# .Q...
# ...Q.
# Q....
# ..Q..
# ....Q
#
# 3th 5 Queens Problem Result:
# .Q...
# ....Q
# ..Q..
# Q....
# ...Q.
#
# 4th 5 Queens Problem Result:
# ..Q..
# Q....
# ...Q.
# .Q...
# ....Q
#
# 5th 5 Queens Problem Result:
# ..Q..
# ....Q
# .Q...
# ...Q.
# Q....
#
# 6th 5 Queens Problem Result:
# ...Q.
# Q....
# ..Q..
# ....Q
# .Q...
#
# 7th 5 Queens Problem Result:
# ...Q.
# .Q...
# ....Q
# ..Q..
# Q....
#
# 8th 5 Queens Problem Result:
# ....Q
# .Q...
# ...Q.
# Q....
# ..Q..
#
# 9th 5 Queens Problem Result:
# ....Q
# ..Q..
# Q....
# ...Q.
# .Q...
#
# ================================= 5 Queens Problem Result =================================
# ================================= 5 Queens Problem Result =================================
#
# ================================= 6 Queens Problem Result =================================
# ================================= 6 Queens Problem Result =================================
# 0th 6 Queens Problem Result:
# .Q....
# ...Q..
# .....Q
# Q.....
# ..Q...
# ....Q.
#
# 1th 6 Queens Problem Result:
# ..Q...
# .....Q
# .Q....
# ....Q.
# Q.....
# ...Q..
#
# 2th 6 Queens Problem Result:
# ...Q..
# Q.....
# ....Q.
# .Q....
# .....Q
# ..Q...
#
# 3th 6 Queens Problem Result:
# ....Q.
# ..Q...
# Q.....
# .....Q
# ...Q..
# .Q....
#
# ================================= 6 Queens Problem Result =================================
# ================================= 6 Queens Problem Result =================================
#
# ================================= 7 Queens Problem Result =================================
# ================================= 7 Queens Problem Result =================================
# 0th 7 Queens Problem Result:
# Q......
# ..Q....
# ....Q..
# ......Q
# .Q.....
# ...Q...
# .....Q.
#
# 1th 7 Queens Problem Result:
# Q......
# ...Q...
# ......Q
# ..Q....
# .....Q.
# .Q.....
# ....Q..
#
# 2th 7 Queens Problem Result:
# Q......
# ....Q..
# .Q.....
# .....Q.
# ..Q....
# ......Q
# ...Q...
#
# 3th 7 Queens Problem Result:
# Q......
# .....Q.
# ...Q...
# .Q.....
# ......Q
# ....Q..
# ..Q....
#
# 4th 7 Queens Problem Result:
# .Q.....
# ...Q...
# Q......
# ......Q
# ....Q..
# ..Q....
# .....Q.
#
# 5th 7 Queens Problem Result:
# .Q.....
# ...Q...
# .....Q.
# Q......
# ..Q....
# ....Q..
# ......Q
#
# 6th 7 Queens Problem Result:
# .Q.....
# ....Q..
# Q......
# ...Q...
# ......Q
# ..Q....
# .....Q.
#
# 7th 7 Queens Problem Result:
# .Q.....
# ....Q..
# ..Q....
# Q......
# ......Q
# ...Q...
# .....Q.
#
# 8th 7 Queens Problem Result:
# .Q.....
# ....Q..
# ......Q
# ...Q...
# Q......
# ..Q....
# .....Q.
#
# 9th 7 Queens Problem Result:
# .Q.....
# .....Q.
# ..Q....
# ......Q
# ...Q...
# Q......
# ....Q..
#
# 10th 7 Queens Problem Result:
# .Q.....
# ......Q
# ....Q..
# ..Q....
# Q......
# .....Q.
# ...Q...
#
# 11th 7 Queens Problem Result:
# ..Q....
# Q......
# .....Q.
# .Q.....
# ....Q..
# ......Q
# ...Q...
#
# 12th 7 Queens Problem Result:
# ..Q....
# Q......
# .....Q.
# ...Q...
# .Q.....
# ......Q
# ....Q..
#
# 13th 7 Queens Problem Result:
# ..Q....
# ....Q..
# ......Q
# .Q.....
# ...Q...
# .....Q.
# Q......
#
# 14th 7 Queens Problem Result:
# ..Q....
# .....Q.
# .Q.....
# ....Q..
# Q......
# ...Q...
# ......Q
#
# 15th 7 Queens Problem Result:
# ..Q....
# ......Q
# .Q.....
# ...Q...
# .....Q.
# Q......
# ....Q..
#
# 16th 7 Queens Problem Result:
# ..Q....
# ......Q
# ...Q...
# Q......
# ....Q..
# .Q.....
# .....Q.
#
# 17th 7 Queens Problem Result:
# ...Q...
# Q......
# ..Q....
# .....Q.
# .Q.....
# ......Q
# ....Q..
#
# 18th 7 Queens Problem Result:
# ...Q...
# Q......
# ....Q..
# .Q.....
# .....Q.
# ..Q....
# ......Q
#
# 19th 7 Queens Problem Result:
# ...Q...
# .Q.....
# ......Q
# ....Q..
# ..Q....
# Q......
# .....Q.
#
# 20th 7 Queens Problem Result:
# ...Q...
# .....Q.
# Q......
# ..Q....
# ....Q..
# ......Q
# .Q.....
#
# 21th 7 Queens Problem Result:
# ...Q...
# ......Q
# ..Q....
# .....Q.
# .Q.....
# ....Q..
# Q......
#
# 22th 7 Queens Problem Result:
# ...Q...
# ......Q
# ....Q..
# .Q.....
# .....Q.
# Q......
# ..Q....
#
# 23th 7 Queens Problem Result:
# ....Q..
# Q......
# ...Q...
# ......Q
# ..Q....
# .....Q.
# .Q.....
#
# 24th 7 Queens Problem Result:
# ....Q..
# Q......
# .....Q.
# ...Q...
# .Q.....
# ......Q
# ..Q....
#
# 25th 7 Queens Problem Result:
# ....Q..
# .Q.....
# .....Q.
# ..Q....
# ......Q
# ...Q...
# Q......
#
# 26th 7 Queens Problem Result:
# ....Q..
# ..Q....
# Q......
# .....Q.
# ...Q...
# .Q.....
# ......Q
#
# 27th 7 Queens Problem Result:
# ....Q..
# ......Q
# .Q.....
# ...Q...
# .....Q.
# Q......
# ..Q....
#
# 28th 7 Queens Problem Result:
# ....Q..
# ......Q
# .Q.....
# .....Q.
# ..Q....
# Q......
# ...Q...
#
# 29th 7 Queens Problem Result:
# .....Q.
# Q......
# ..Q....
# ....Q..
# ......Q
# .Q.....
# ...Q...
#
# 30th 7 Queens Problem Result:
# .....Q.
# .Q.....
# ....Q..
# Q......
# ...Q...
# ......Q
# ..Q....
#
# 31th 7 Queens Problem Result:
# .....Q.
# ..Q....
# Q......
# ...Q...
# ......Q
# ....Q..
# .Q.....
#
# 32th 7 Queens Problem Result:
# .....Q.
# ..Q....
# ....Q..
# ......Q
# Q......
# ...Q...
# .Q.....
#
# 33th 7 Queens Problem Result:
# .....Q.
# ..Q....
# ......Q
# ...Q...
# Q......
# ....Q..
# .Q.....
#
# 34th 7 Queens Problem Result:
# .....Q.
# ...Q...
# .Q.....
# ......Q
# ....Q..
# ..Q....
# Q......
#
# 35th 7 Queens Problem Result:
# .....Q.
# ...Q...
# ......Q
# Q......
# ..Q....
# ....Q..
# .Q.....
#
# 36th 7 Queens Problem Result:
# ......Q
# .Q.....
# ...Q...
# .....Q.
# Q......
# ..Q....
# ....Q..
#
# 37th 7 Queens Problem Result:
# ......Q
# ..Q....
# .....Q.
# .Q.....
# ....Q..
# Q......
# ...Q...
#
# 38th 7 Queens Problem Result:
# ......Q
# ...Q...
# Q......
# ....Q..
# .Q.....
# .....Q.
# ..Q....
#
# 39th 7 Queens Problem Result:
# ......Q
# ....Q..
# ..Q....
# Q......
# .....Q.
# ...Q...
# .Q.....
#
# ================================= 7 Queens Problem Result =================================
# ================================= 7 Queens Problem Result =================================
#
# ================================= 8 Queens Problem Result =================================
# ================================= 8 Queens Problem Result =================================
# 0th 8 Queens Problem Result:
# Q.......
# ....Q...
# .......Q
# .....Q..
# ..Q.....
# ......Q.
# .Q......
# ...Q....
#
# 1th 8 Queens Problem Result:
# Q.......
# .....Q..
# .......Q
# ..Q.....
# ......Q.
# ...Q....
# .Q......
# ....Q...
#
# 2th 8 Queens Problem Result:
# Q.......
# ......Q.
# ...Q....
# .....Q..
# .......Q
# .Q......
# ....Q...
# ..Q.....
#
# 3th 8 Queens Problem Result:
# Q.......
# ......Q.
# ....Q...
# .......Q
# .Q......
# ...Q....
# .....Q..
# ..Q.....
#
# 4th 8 Queens Problem Result:
# .Q......
# ...Q....
# .....Q..
# .......Q
# ..Q.....
# Q.......
# ......Q.
# ....Q...
#
# 5th 8 Queens Problem Result:
# .Q......
# ....Q...
# ......Q.
# Q.......
# ..Q.....
# .......Q
# .....Q..
# ...Q....
#
# 6th 8 Queens Problem Result:
# .Q......
# ....Q...
# ......Q.
# ...Q....
# Q.......
# .......Q
# .....Q..
# ..Q.....
#
# 7th 8 Queens Problem Result:
# .Q......
# .....Q..
# Q.......
# ......Q.
# ...Q....
# .......Q
# ..Q.....
# ....Q...
#
# 8th 8 Queens Problem Result:
# .Q......
# .....Q..
# .......Q
# ..Q.....
# Q.......
# ...Q....
# ......Q.
# ....Q...
#
# 9th 8 Queens Problem Result:
# .Q......
# ......Q.
# ..Q.....
# .....Q..
# .......Q
# ....Q...
# Q.......
# ...Q....
#
# 10th 8 Queens Problem Result:
# .Q......
# ......Q.
# ....Q...
# .......Q
# Q.......
# ...Q....
# .....Q..
# ..Q.....
#
# 11th 8 Queens Problem Result:
# .Q......
# .......Q
# .....Q..
# Q.......
# ..Q.....
# ....Q...
# ......Q.
# ...Q....
#
# 12th 8 Queens Problem Result:
# ..Q.....
# Q.......
# ......Q.
# ....Q...
# .......Q
# .Q......
# ...Q....
# .....Q..
#
# 13th 8 Queens Problem Result:
# ..Q.....
# ....Q...
# .Q......
# .......Q
# Q.......
# ......Q.
# ...Q....
# .....Q..
#
# 14th 8 Queens Problem Result:
# ..Q.....
# ....Q...
# .Q......
# .......Q
# .....Q..
# ...Q....
# ......Q.
# Q.......
#
# 15th 8 Queens Problem Result:
# ..Q.....
# ....Q...
# ......Q.
# Q.......
# ...Q....
# .Q......
# .......Q
# .....Q..
#
# 16th 8 Queens Problem Result:
# ..Q.....
# ....Q...
# .......Q
# ...Q....
# Q.......
# ......Q.
# .Q......
# .....Q..
#
# 17th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .Q......
# ....Q...
# .......Q
# Q.......
# ......Q.
# ...Q....
#
# 18th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .Q......
# ......Q.
# Q.......
# ...Q....
# .......Q
# ....Q...
#
# 19th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .Q......
# ......Q.
# ....Q...
# Q.......
# .......Q
# ...Q....
#
# 20th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# ...Q....
# Q.......
# .......Q
# ....Q...
# ......Q.
# .Q......
#
# 21th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# ...Q....
# .Q......
# .......Q
# ....Q...
# ......Q.
# Q.......
#
# 22th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .......Q
# Q.......
# ...Q....
# ......Q.
# ....Q...
# .Q......
#
# 23th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .......Q
# Q.......
# ....Q...
# ......Q.
# .Q......
# ...Q....
#
# 24th 8 Queens Problem Result:
# ..Q.....
# .....Q..
# .......Q
# .Q......
# ...Q....
# Q.......
# ......Q.
# ....Q...
#
# 25th 8 Queens Problem Result:
# ..Q.....
# ......Q.
# .Q......
# .......Q
# ....Q...
# Q.......
# ...Q....
# .....Q..
#
# 26th 8 Queens Problem Result:
# ..Q.....
# ......Q.
# .Q......
# .......Q
# .....Q..
# ...Q....
# Q.......
# ....Q...
#
# 27th 8 Queens Problem Result:
# ..Q.....
# .......Q
# ...Q....
# ......Q.
# Q.......
# .....Q..
# .Q......
# ....Q...
#
# 28th 8 Queens Problem Result:
# ...Q....
# Q.......
# ....Q...
# .......Q
# .Q......
# ......Q.
# ..Q.....
# .....Q..
#
# 29th 8 Queens Problem Result:
# ...Q....
# Q.......
# ....Q...
# .......Q
# .....Q..
# ..Q.....
# ......Q.
# .Q......
#
# 30th 8 Queens Problem Result:
# ...Q....
# .Q......
# ....Q...
# .......Q
# .....Q..
# Q.......
# ..Q.....
# ......Q.
#
# 31th 8 Queens Problem Result:
# ...Q....
# .Q......
# ......Q.
# ..Q.....
# .....Q..
# .......Q
# Q.......
# ....Q...
#
# 32th 8 Queens Problem Result:
# ...Q....
# .Q......
# ......Q.
# ..Q.....
# .....Q..
# .......Q
# ....Q...
# Q.......
#
# 33th 8 Queens Problem Result:
# ...Q....
# .Q......
# ......Q.
# ....Q...
# Q.......
# .......Q
# .....Q..
# ..Q.....
#
# 34th 8 Queens Problem Result:
# ...Q....
# .Q......
# .......Q
# ....Q...
# ......Q.
# Q.......
# ..Q.....
# .....Q..
#
# 35th 8 Queens Problem Result:
# ...Q....
# .Q......
# .......Q
# .....Q..
# Q.......
# ..Q.....
# ....Q...
# ......Q.
#
# 36th 8 Queens Problem Result:
# ...Q....
# .....Q..
# Q.......
# ....Q...
# .Q......
# .......Q
# ..Q.....
# ......Q.
#
# 37th 8 Queens Problem Result:
# ...Q....
# .....Q..
# .......Q
# .Q......
# ......Q.
# Q.......
# ..Q.....
# ....Q...
#
# 38th 8 Queens Problem Result:
# ...Q....
# .....Q..
# .......Q
# ..Q.....
# Q.......
# ......Q.
# ....Q...
# .Q......
#
# 39th 8 Queens Problem Result:
# ...Q....
# ......Q.
# Q.......
# .......Q
# ....Q...
# .Q......
# .....Q..
# ..Q.....
#
# 40th 8 Queens Problem Result:
# ...Q....
# ......Q.
# ..Q.....
# .......Q
# .Q......
# ....Q...
# Q.......
# .....Q..
#
# 41th 8 Queens Problem Result:
# ...Q....
# ......Q.
# ....Q...
# .Q......
# .....Q..
# Q.......
# ..Q.....
# .......Q
#
# 42th 8 Queens Problem Result:
# ...Q....
# ......Q.
# ....Q...
# ..Q.....
# Q.......
# .....Q..
# .......Q
# .Q......
#
# 43th 8 Queens Problem Result:
# ...Q....
# .......Q
# Q.......
# ..Q.....
# .....Q..
# .Q......
# ......Q.
# ....Q...
#
# 44th 8 Queens Problem Result:
# ...Q....
# .......Q
# Q.......
# ....Q...
# ......Q.
# .Q......
# .....Q..
# ..Q.....
#
# 45th 8 Queens Problem Result:
# ...Q....
# .......Q
# ....Q...
# ..Q.....
# Q.......
# ......Q.
# .Q......
# .....Q..
#
# 46th 8 Queens Problem Result:
# ....Q...
# Q.......
# ...Q....
# .....Q..
# .......Q
# .Q......
# ......Q.
# ..Q.....
#
# 47th 8 Queens Problem Result:
# ....Q...
# Q.......
# .......Q
# ...Q....
# .Q......
# ......Q.
# ..Q.....
# .....Q..
#
# 48th 8 Queens Problem Result:
# ....Q...
# Q.......
# .......Q
# .....Q..
# ..Q.....
# ......Q.
# .Q......
# ...Q....
#
# 49th 8 Queens Problem Result:
# ....Q...
# .Q......
# ...Q....
# .....Q..
# .......Q
# ..Q.....
# Q.......
# ......Q.
#
# 50th 8 Queens Problem Result:
# ....Q...
# .Q......
# ...Q....
# ......Q.
# ..Q.....
# .......Q
# .....Q..
# Q.......
#
# 51th 8 Queens Problem Result:
# ....Q...
# .Q......
# .....Q..
# Q.......
# ......Q.
# ...Q....
# .......Q
# ..Q.....
#
# 52th 8 Queens Problem Result:
# ....Q...
# .Q......
# .......Q
# Q.......
# ...Q....
# ......Q.
# ..Q.....
# .....Q..
#
# 53th 8 Queens Problem Result:
# ....Q...
# ..Q.....
# Q.......
# .....Q..
# .......Q
# .Q......
# ...Q....
# ......Q.
#
# 54th 8 Queens Problem Result:
# ....Q...
# ..Q.....
# Q.......
# ......Q.
# .Q......
# .......Q
# .....Q..
# ...Q....
#
# 55th 8 Queens Problem Result:
# ....Q...
# ..Q.....
# .......Q
# ...Q....
# ......Q.
# Q.......
# .....Q..
# .Q......
#
# 56th 8 Queens Problem Result:
# ....Q...
# ......Q.
# Q.......
# ..Q.....
# .......Q
# .....Q..
# ...Q....
# .Q......
#
# 57th 8 Queens Problem Result:
# ....Q...
# ......Q.
# Q.......
# ...Q....
# .Q......
# .......Q
# .....Q..
# ..Q.....
#
# 58th 8 Queens Problem Result:
# ....Q...
# ......Q.
# .Q......
# ...Q....
# .......Q
# Q.......
# ..Q.....
# .....Q..
#
# 59th 8 Queens Problem Result:
# ....Q...
# ......Q.
# .Q......
# .....Q..
# ..Q.....
# Q.......
# ...Q....
# .......Q
#
# 60th 8 Queens Problem Result:
# ....Q...
# ......Q.
# .Q......
# .....Q..
# ..Q.....
# Q.......
# .......Q
# ...Q....
#
# 61th 8 Queens Problem Result:
# ....Q...
# ......Q.
# ...Q....
# Q.......
# ..Q.....
# .......Q
# .....Q..
# .Q......
#
# 62th 8 Queens Problem Result:
# ....Q...
# .......Q
# ...Q....
# Q.......
# ..Q.....
# .....Q..
# .Q......
# ......Q.
#
# 63th 8 Queens Problem Result:
# ....Q...
# .......Q
# ...Q....
# Q.......
# ......Q.
# .Q......
# .....Q..
# ..Q.....
#
# 64th 8 Queens Problem Result:
# .....Q..
# Q.......
# ....Q...
# .Q......
# .......Q
# ..Q.....
# ......Q.
# ...Q....
#
# 65th 8 Queens Problem Result:
# .....Q..
# .Q......
# ......Q.
# Q.......
# ..Q.....
# ....Q...
# .......Q
# ...Q....
#
# 66th 8 Queens Problem Result:
# .....Q..
# .Q......
# ......Q.
# Q.......
# ...Q....
# .......Q
# ....Q...
# ..Q.....
#
# 67th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# Q.......
# ......Q.
# ....Q...
# .......Q
# .Q......
# ...Q....
#
# 68th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# Q.......
# .......Q
# ...Q....
# .Q......
# ......Q.
# ....Q...
#
# 69th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# Q.......
# .......Q
# ....Q...
# .Q......
# ...Q....
# ......Q.
#
# 70th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# ....Q...
# ......Q.
# Q.......
# ...Q....
# .Q......
# .......Q
#
# 71th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# ....Q...
# .......Q
# Q.......
# ...Q....
# .Q......
# ......Q.
#
# 72th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# ......Q.
# .Q......
# ...Q....
# .......Q
# Q.......
# ....Q...
#
# 73th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# ......Q.
# .Q......
# .......Q
# ....Q...
# Q.......
# ...Q....
#
# 74th 8 Queens Problem Result:
# .....Q..
# ..Q.....
# ......Q.
# ...Q....
# Q.......
# .......Q
# .Q......
# ....Q...
#
# 75th 8 Queens Problem Result:
# .....Q..
# ...Q....
# Q.......
# ....Q...
# .......Q
# .Q......
# ......Q.
# ..Q.....
#
# 76th 8 Queens Problem Result:
# .....Q..
# ...Q....
# .Q......
# .......Q
# ....Q...
# ......Q.
# Q.......
# ..Q.....
#
# 77th 8 Queens Problem Result:
# .....Q..
# ...Q....
# ......Q.
# Q.......
# ..Q.....
# ....Q...
# .Q......
# .......Q
#
# 78th 8 Queens Problem Result:
# .....Q..
# ...Q....
# ......Q.
# Q.......
# .......Q
# .Q......
# ....Q...
# ..Q.....
#
# 79th 8 Queens Problem Result:
# .....Q..
# .......Q
# .Q......
# ...Q....
# Q.......
# ......Q.
# ....Q...
# ..Q.....
#
# 80th 8 Queens Problem Result:
# ......Q.
# Q.......
# ..Q.....
# .......Q
# .....Q..
# ...Q....
# .Q......
# ....Q...
#
# 81th 8 Queens Problem Result:
# ......Q.
# .Q......
# ...Q....
# Q.......
# .......Q
# ....Q...
# ..Q.....
# .....Q..
#
# 82th 8 Queens Problem Result:
# ......Q.
# .Q......
# .....Q..
# ..Q.....
# Q.......
# ...Q....
# .......Q
# ....Q...
#
# 83th 8 Queens Problem Result:
# ......Q.
# ..Q.....
# Q.......
# .....Q..
# .......Q
# ....Q...
# .Q......
# ...Q....
#
# 84th 8 Queens Problem Result:
# ......Q.
# ..Q.....
# .......Q
# .Q......
# ....Q...
# Q.......
# .....Q..
# ...Q....
#
# 85th 8 Queens Problem Result:
# ......Q.
# ...Q....
# .Q......
# ....Q...
# .......Q
# Q.......
# ..Q.....
# .....Q..
#
# 86th 8 Queens Problem Result:
# ......Q.
# ...Q....
# .Q......
# .......Q
# .....Q..
# Q.......
# ..Q.....
# ....Q...
#
# 87th 8 Queens Problem Result:
# ......Q.
# ....Q...
# ..Q.....
# Q.......
# .....Q..
# .......Q
# .Q......
# ...Q....
#
# 88th 8 Queens Problem Result:
# .......Q
# .Q......
# ...Q....
# Q.......
# ......Q.
# ....Q...
# ..Q.....
# .....Q..
#
# 89th 8 Queens Problem Result:
# .......Q
# .Q......
# ....Q...
# ..Q.....
# Q.......
# ......Q.
# ...Q....
# .....Q..
#
# 90th 8 Queens Problem Result:
# .......Q
# ..Q.....
# Q.......
# .....Q..
# .Q......
# ....Q...
# ......Q.
# ...Q....
#
# 91th 8 Queens Problem Result:
# .......Q
# ...Q....
# Q.......
# ..Q.....
# .....Q..
# .Q......
# ......Q.
# ....Q...
#
# ================================= 8 Queens Problem Result =================================
# ================================= 8 Queens Problem Result =================================
#
# ================================= 9 Queens Problem Result =================================
# ================================= 9 Queens Problem Result =================================
# 0th 9 Queens Problem Result:
# Q........
# ..Q......
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ....Q....
#
# 1th 9 Queens Problem Result:
# Q........
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
# ........Q
# ...Q.....
# .....Q...
#
# 2th 9 Queens Problem Result:
# Q........
# ..Q......
# .......Q.
# .....Q...
# ........Q
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
#
# 3th 9 Queens Problem Result:
# Q........
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ........Q
# ..Q......
# ....Q....
# ......Q..
#
# 4th 9 Queens Problem Result:
# Q........
# ...Q.....
# .....Q...
# ..Q......
# ........Q
# .Q.......
# .......Q.
# ....Q....
# ......Q..
#
# 5th 9 Queens Problem Result:
# Q........
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ....Q....
# ..Q......
# ........Q
# ......Q..
#
# 6th 9 Queens Problem Result:
# Q........
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
# ........Q
# .....Q...
#
# 7th 9 Queens Problem Result:
# Q........
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# ..Q......
#
# 8th 9 Queens Problem Result:
# Q........
# ...Q.....
# .......Q.
# ..Q......
# ........Q
# ......Q..
# ....Q....
# .Q.......
# .....Q...
#
# 9th 9 Queens Problem Result:
# Q........
# ....Q....
# .Q.......
# .....Q...
# ........Q
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
#
# 10th 9 Queens Problem Result:
# Q........
# ....Q....
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# ........Q
# ...Q.....
# .......Q.
#
# 11th 9 Queens Problem Result:
# Q........
# ....Q....
# ......Q..
# ........Q
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
#
# 12th 9 Queens Problem Result:
# Q........
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ..Q......
#
# 13th 9 Queens Problem Result:
# Q........
# ....Q....
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
#
# 14th 9 Queens Problem Result:
# Q........
# ....Q....
# ........Q
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
#
# 15th 9 Queens Problem Result:
# Q........
# .....Q...
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ....Q....
#
# 16th 9 Queens Problem Result:
# Q........
# .....Q...
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# ..Q......
# ....Q....
# .......Q.
#
# 17th 9 Queens Problem Result:
# Q........
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
# ........Q
# ......Q..
# ....Q....
#
# 18th 9 Queens Problem Result:
# Q........
# .....Q...
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# ....Q....
#
# 19th 9 Queens Problem Result:
# Q........
# .....Q...
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ..Q......
#
# 20th 9 Queens Problem Result:
# Q........
# .....Q...
# ........Q
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
#
# 21th 9 Queens Problem Result:
# Q........
# ......Q..
# ...Q.....
# .....Q...
# ........Q
# .Q.......
# ....Q....
# ..Q......
# .......Q.
#
# 22th 9 Queens Problem Result:
# Q........
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ....Q....
# ........Q
# .Q.......
# .....Q...
#
# 23th 9 Queens Problem Result:
# Q........
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ........Q
# .....Q...
# .Q.......
# ....Q....
#
# 24th 9 Queens Problem Result:
# Q........
# ......Q..
# ....Q....
# .......Q.
# .Q.......
# ........Q
# ..Q......
# .....Q...
# ...Q.....
#
# 25th 9 Queens Problem Result:
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# .....Q...
# ..Q......
# ....Q....
#
# 26th 9 Queens Problem Result:
# Q........
# .......Q.
# ....Q....
# ..Q......
# .....Q...
# ........Q
# .Q.......
# ...Q.....
# ......Q..
#
# 27th 9 Queens Problem Result:
# Q........
# .......Q.
# ....Q....
# ..Q......
# ........Q
# ......Q..
# .Q.......
# ...Q.....
# .....Q...
#
# 28th 9 Queens Problem Result:
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ........Q
# .....Q...
# ..Q......
# ....Q....
# .......Q.
#
# 29th 9 Queens Problem Result:
# .Q.......
# ...Q.....
# ......Q..
# Q........
# ..Q......
# ........Q
# .....Q...
# .......Q.
# ....Q....
#
# 30th 9 Queens Problem Result:
# .Q.......
# ...Q.....
# .......Q.
# ..Q......
# ........Q
# .....Q...
# Q........
# ....Q....
# ......Q..
#
# 31th 9 Queens Problem Result:
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ..Q......
# Q........
# .....Q...
# .......Q.
# ....Q....
#
# 32th 9 Queens Problem Result:
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ....Q....
# ..Q......
# Q........
# .....Q...
# .......Q.
#
# 33th 9 Queens Problem Result:
# .Q.......
# ....Q....
# ......Q..
# Q........
# ..Q......
# .......Q.
# .....Q...
# ...Q.....
# ........Q
#
# 34th 9 Queens Problem Result:
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
# Q........
# ..Q......
# ........Q
# .....Q...
# .......Q.
#
# 35th 9 Queens Problem Result:
# .Q.......
# ....Q....
# ......Q..
# ........Q
# ..Q......
# .....Q...
# ...Q.....
# Q........
# .......Q.
#
# 36th 9 Queens Problem Result:
# .Q.......
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .......Q.
# Q........
# ..Q......
# .....Q...
#
# 37th 9 Queens Problem Result:
# .Q.......
# ....Q....
# .......Q.
# Q........
# ..Q......
# .....Q...
# ........Q
# ......Q..
# ...Q.....
#
# 38th 9 Queens Problem Result:
# .Q.......
# ....Q....
# .......Q.
# Q........
# ........Q
# .....Q...
# ..Q......
# ......Q..
# ...Q.....
#
# 39th 9 Queens Problem Result:
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# ........Q
# ..Q......
# Q........
# ...Q.....
# ......Q..
#
# 40th 9 Queens Problem Result:
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# ........Q
# ..Q......
# Q........
# ......Q..
# ...Q.....
#
# 41th 9 Queens Problem Result:
# .Q.......
# ....Q....
# ........Q
# ...Q.....
# Q........
# .......Q.
# .....Q...
# ..Q......
# ......Q..
#
# 42th 9 Queens Problem Result:
# .Q.......
# .....Q...
# Q........
# ..Q......
# ......Q..
# ........Q
# ...Q.....
# .......Q.
# ....Q....
#
# 43th 9 Queens Problem Result:
# .Q.......
# .....Q...
# Q........
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ....Q....
# ........Q
#
# 44th 9 Queens Problem Result:
# .Q.......
# .....Q...
# Q........
# ......Q..
# ....Q....
# ..Q......
# ........Q
# ...Q.....
# .......Q.
#
# 45th 9 Queens Problem Result:
# .Q.......
# .....Q...
# Q........
# ........Q
# ....Q....
# .......Q.
# ...Q.....
# ......Q..
# ..Q......
#
# 46th 9 Queens Problem Result:
# .Q.......
# .....Q...
# ..Q......
# Q........
# .......Q.
# ...Q.....
# ........Q
# ......Q..
# ....Q....
#
# 47th 9 Queens Problem Result:
# .Q.......
# .....Q...
# ........Q
# ..Q......
# ....Q....
# .......Q.
# ...Q.....
# Q........
# ......Q..
#
# 48th 9 Queens Problem Result:
# .Q.......
# ......Q..
# ....Q....
# Q........
# ........Q
# ...Q.....
# .....Q...
# .......Q.
# ..Q......
#
# 49th 9 Queens Problem Result:
# .Q.......
# ......Q..
# ....Q....
# .......Q.
# Q........
# ...Q.....
# .....Q...
# ..Q......
# ........Q
#
# 50th 9 Queens Problem Result:
# .Q.......
# ......Q..
# ........Q
# .....Q...
# ..Q......
# Q........
# ...Q.....
# .......Q.
# ....Q....
#
# 51th 9 Queens Problem Result:
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ........Q
# .....Q...
# ..Q......
# ....Q....
#
# 52th 9 Queens Problem Result:
# .Q.......
# .......Q.
# ....Q....
# ..Q......
# ........Q
# .....Q...
# ...Q.....
# Q........
# ......Q..
#
# 53th 9 Queens Problem Result:
# .Q.......
# .......Q.
# .....Q...
# ........Q
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ....Q....
#
# 54th 9 Queens Problem Result:
# .Q.......
# ........Q
# ....Q....
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# Q........
# .....Q...
#
# 55th 9 Queens Problem Result:
# .Q.......
# ........Q
# .....Q...
# ..Q......
# ....Q....
# .......Q.
# Q........
# ...Q.....
# ......Q..
#
# 56th 9 Queens Problem Result:
# .Q.......
# ........Q
# .....Q...
# ..Q......
# ......Q..
# ...Q.....
# Q........
# .......Q.
# ....Q....
#
# 57th 9 Queens Problem Result:
# .Q.......
# ........Q
# .....Q...
# ...Q.....
# ......Q..
# Q........
# ..Q......
# ....Q....
# .......Q.
#
# 58th 9 Queens Problem Result:
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# ....Q....
# .......Q.
# .....Q...
#
# 59th 9 Queens Problem Result:
# ..Q......
# Q........
# .....Q...
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# ........Q
# ......Q..
#
# 60th 9 Queens Problem Result:
# ..Q......
# Q........
# ......Q..
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
# ........Q
# ....Q....
#
# 61th 9 Queens Problem Result:
# ..Q......
# Q........
# ......Q..
# ....Q....
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
# ........Q
#
# 62th 9 Queens Problem Result:
# ..Q......
# Q........
# .......Q.
# ...Q.....
# ........Q
# ......Q..
# ....Q....
# .Q.......
# .....Q...
#
# 63th 9 Queens Problem Result:
# ..Q......
# Q........
# ........Q
# ......Q..
# ....Q....
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
#
# 64th 9 Queens Problem Result:
# ..Q......
# ....Q....
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ........Q
# .....Q...
#
# 65th 9 Queens Problem Result:
# ..Q......
# ....Q....
# .Q.......
# .......Q.
# Q........
# ......Q..
# ...Q.....
# .....Q...
# ........Q
#
# 66th 9 Queens Problem Result:
# ..Q......
# ....Q....
# ......Q..
# Q........
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ........Q
#
# 67th 9 Queens Problem Result:
# ..Q......
# ....Q....
# .......Q.
# .Q.......
# ........Q
# .....Q...
# Q........
# ......Q..
# ...Q.....
#
# 68th 9 Queens Problem Result:
# ..Q......
# ....Q....
# .......Q.
# .Q.......
# ........Q
# ......Q..
# Q........
# ...Q.....
# .....Q...
#
# 69th 9 Queens Problem Result:
# ..Q......
# ....Q....
# ........Q
# .Q.......
# ...Q.....
# ......Q..
# Q........
# .......Q.
# .....Q...
#
# 70th 9 Queens Problem Result:
# ..Q......
# ....Q....
# ........Q
# ...Q.....
# Q........
# ......Q..
# .Q.......
# .....Q...
# .......Q.
#
# 71th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# Q........
# ...Q.....
# .......Q.
# ....Q....
# ........Q
#
# 72th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .Q.......
# ........Q
# ....Q....
# Q........
# .......Q.
# ...Q.....
# ......Q..
#
# 73th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
# ........Q
#
# 74th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .......Q.
# Q........
# ....Q....
# ........Q
# .Q.......
# ...Q.....
# ......Q..
#
# 75th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ....Q....
# Q........
#
# 76th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .......Q.
# ....Q....
# Q........
# ........Q
# ......Q..
# .Q.......
# ...Q.....
#
# 77th 9 Queens Problem Result:
# ..Q......
# .....Q...
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# Q........
#
# 78th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ....Q....
#
# 79th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
# Q........
# .......Q.
#
# 80th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ....Q....
#
# 81th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# ....Q....
# .......Q.
# Q........
# ...Q.....
# .Q.......
# ......Q..
#
# 82th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# ......Q..
# Q........
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
#
# 83th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
# ....Q....
#
# 84th 9 Queens Problem Result:
# ..Q......
# .....Q...
# ........Q
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .Q.......
# ....Q....
#
# 85th 9 Queens Problem Result:
# ..Q......
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
# ....Q....
# ........Q
# .....Q...
#
# 86th 9 Queens Problem Result:
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
# ........Q
# Q........
# .....Q...
# ...Q.....
#
# 87th 9 Queens Problem Result:
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
# Q........
# ....Q....
# ........Q
#
# 88th 9 Queens Problem Result:
# ..Q......
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# ....Q....
# Q........
# .......Q.
# .....Q...
#
# 89th 9 Queens Problem Result:
# ..Q......
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# .....Q...
# Q........
# ....Q....
# .......Q.
#
# 90th 9 Queens Problem Result:
# ..Q......
# ......Q..
# ...Q.....
# .......Q.
# ....Q....
# ........Q
# Q........
# .....Q...
# .Q.......
#
# 91th 9 Queens Problem Result:
# ..Q......
# ......Q..
# ........Q
# Q........
# ....Q....
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
#
# 92th 9 Queens Problem Result:
# ..Q......
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# Q........
#
# 93th 9 Queens Problem Result:
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ....Q....
# Q........
# .....Q...
#
# 94th 9 Queens Problem Result:
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# ....Q....
# Q........
# .....Q...
#
# 95th 9 Queens Problem Result:
# ..Q......
# .......Q.
# .....Q...
# Q........
# ........Q
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
#
# 96th 9 Queens Problem Result:
# ..Q......
# .......Q.
# .....Q...
# ...Q.....
# ........Q
# Q........
# ....Q....
# ......Q..
# .Q.......
#
# 97th 9 Queens Problem Result:
# ..Q......
# .......Q.
# .....Q...
# ........Q
# .Q.......
# ....Q....
# Q........
# ...Q.....
# ......Q..
#
# 98th 9 Queens Problem Result:
# ..Q......
# ........Q
# .Q.......
# ....Q....
# .......Q.
# Q........
# ......Q..
# ...Q.....
# .....Q...
#
# 99th 9 Queens Problem Result:
# ..Q......
# ........Q
# ...Q.....
# Q........
# .......Q.
# .....Q...
# .Q.......
# ......Q..
# ....Q....
#
# 100th 9 Queens Problem Result:
# ..Q......
# ........Q
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# Q........
# ......Q..
# ....Q....
#
# 101th 9 Queens Problem Result:
# ..Q......
# ........Q
# ...Q.....
# .......Q.
# ....Q....
# .Q.......
# .....Q...
# Q........
# ......Q..
#
# 102th 9 Queens Problem Result:
# ..Q......
# ........Q
# .....Q...
# .Q.......
# ....Q....
# ......Q..
# Q........
# ...Q.....
# .......Q.
#
# 103th 9 Queens Problem Result:
# ..Q......
# ........Q
# .....Q...
# ...Q.....
# Q........
# ......Q..
# ....Q....
# .Q.......
# .......Q.
#
# 104th 9 Queens Problem Result:
# ..Q......
# ........Q
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ....Q....
#
# 105th 9 Queens Problem Result:
# ...Q.....
# Q........
# ..Q......
# .....Q...
# ........Q
# .Q.......
# .......Q.
# ....Q....
# ......Q..
#
# 106th 9 Queens Problem Result:
# ...Q.....
# Q........
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ..Q......
# .......Q.
# .....Q...
#
# 107th 9 Queens Problem Result:
# ...Q.....
# Q........
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
# .....Q...
# ........Q
#
# 108th 9 Queens Problem Result:
# ...Q.....
# Q........
# ....Q....
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# ......Q..
#
# 109th 9 Queens Problem Result:
# ...Q.....
# Q........
# ......Q..
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# ....Q....
#
# 110th 9 Queens Problem Result:
# ...Q.....
# Q........
# ........Q
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
#
# 111th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
# Q........
# ..Q......
# .....Q...
# ........Q
# ......Q..
#
# 112th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ......Q..
# ..Q......
# Q........
# .......Q.
# ....Q....
# ........Q
# .....Q...
#
# 113th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# Q........
# ....Q....
# .......Q.
# .....Q...
# ..Q......
#
# 114th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# Q........
# .......Q.
# ....Q....
# ..Q......
# .....Q...
#
# 115th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
# ........Q
# ......Q..
# ....Q....
# Q........
# .....Q...
#
# 116th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ........Q
# ..Q......
# .....Q...
# .......Q.
# Q........
# ....Q....
# ......Q..
#
# 117th 9 Queens Problem Result:
# ...Q.....
# .Q.......
# ........Q
# ....Q....
# Q........
# .......Q.
# .....Q...
# ..Q......
# ......Q..
#
# 118th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# Q........
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
# ........Q
#
# 119th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# Q........
# ........Q
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
#
# 120th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# Q........
# ........Q
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
#
# 121th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# ..Q......
# ........Q
# .Q.......
# ....Q....
# .......Q.
# Q........
# ......Q..
#
# 122th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# ..Q......
# ........Q
# .Q.......
# .......Q.
# ....Q....
# ......Q..
# Q........
#
# 123th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# ..Q......
# ........Q
# ......Q..
# Q........
# .......Q.
# .Q.......
# ....Q....
#
# 124th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ....Q....
# Q........
# ........Q
# ......Q..
# ..Q......
#
# 125th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ....Q....
# ......Q..
# ........Q
# Q........
# ..Q......
#
# 126th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ......Q..
# Q........
# ..Q......
# ....Q....
# ........Q
#
# 127th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# .......Q.
# ..Q......
# Q........
# ......Q..
# ....Q....
# .Q.......
# ........Q
#
# 128th 9 Queens Problem Result:
# ...Q.....
# .....Q...
# ........Q
# ..Q......
# Q........
# .......Q.
# .Q.......
# ....Q....
# ......Q..
#
# 129th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# Q........
# ..Q......
# ........Q
# .....Q...
# .......Q.
# ....Q....
# .Q.......
#
# 130th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# Q........
# .....Q...
# ........Q
# .Q.......
# .......Q.
# ....Q....
# ..Q......
#
# 131th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# Q........
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ..Q......
# .....Q...
#
# 132th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ..Q......
# .....Q...
# ........Q
# Q........
# .......Q.
# ....Q....
# .Q.......
#
# 133th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
# ........Q
# .....Q...
# Q........
#
# 134th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .....Q...
# Q........
# ........Q
# .Q.......
# ....Q....
#
# 135th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
# ....Q....
# Q........
#
# 136th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
# ........Q
# Q........
# ..Q......
# .......Q.
# .....Q...
#
# 137th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
# ........Q
# Q........
# .....Q...
# .......Q.
# ..Q......
#
# 138th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
# ........Q
# .....Q...
# .......Q.
# ..Q......
# Q........
#
# 139th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# ....Q....
# .......Q.
# Q........
# ..Q......
# .....Q...
#
# 140th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# .....Q...
# Q........
# ..Q......
# ....Q....
# .......Q.
#
# 141th 9 Queens Problem Result:
# ...Q.....
# ......Q..
# ........Q
# .....Q...
# ..Q......
# Q........
# .......Q.
# ....Q....
# .Q.......
#
# 142th 9 Queens Problem Result:
# ...Q.....
# .......Q.
# Q........
# ....Q....
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# ........Q
#
# 143th 9 Queens Problem Result:
# ...Q.....
# .......Q.
# ....Q....
# ..Q......
# Q........
# .....Q...
# .Q.......
# ........Q
# ......Q..
#
# 144th 9 Queens Problem Result:
# ...Q.....
# .......Q.
# ....Q....
# ..Q......
# Q........
# ......Q..
# .Q.......
# .....Q...
# ........Q
#
# 145th 9 Queens Problem Result:
# ...Q.....
# ........Q
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# ....Q....
# Q........
# .......Q.
#
# 146th 9 Queens Problem Result:
# ...Q.....
# ........Q
# ....Q....
# ..Q......
# Q........
# .....Q...
# .......Q.
# .Q.......
# ......Q..
#
# 147th 9 Queens Problem Result:
# ...Q.....
# ........Q
# ....Q....
# ..Q......
# Q........
# ......Q..
# .Q.......
# .......Q.
# .....Q...
#
# 148th 9 Queens Problem Result:
# ...Q.....
# ........Q
# ....Q....
# .......Q.
# Q........
# ..Q......
# .....Q...
# .Q.......
# ......Q..
#
# 149th 9 Queens Problem Result:
# ....Q....
# Q........
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
# ........Q
# ......Q..
#
# 150th 9 Queens Problem Result:
# ....Q....
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# .....Q...
# ..Q......
#
# 151th 9 Queens Problem Result:
# ....Q....
# Q........
# .......Q.
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# ...Q.....
# ........Q
#
# 152th 9 Queens Problem Result:
# ....Q....
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ........Q
# ..Q......
# .....Q...
# .......Q.
#
# 153th 9 Queens Problem Result:
# ....Q....
# .Q.......
# ...Q.....
# ........Q
# ......Q..
# ..Q......
# Q........
# .....Q...
# .......Q.
#
# 154th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .....Q...
# Q........
# ..Q......
# ......Q..
# ........Q
# ...Q.....
# .......Q.
#
# 155th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .....Q...
# ........Q
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# Q........
#
# 156th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .....Q...
# ........Q
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .......Q.
#
# 157th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ........Q
# .....Q...
# ..Q......
#
# 158th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .......Q.
# Q........
# ......Q..
# ........Q
# ..Q......
# .....Q...
# ...Q.....
#
# 159th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
# Q........
# ........Q
# .....Q...
#
# 160th 9 Queens Problem Result:
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
# ........Q
# Q........
# .....Q...
# ...Q.....
#
# 161th 9 Queens Problem Result:
# ....Q....
# .Q.......
# ........Q
# Q........
# .....Q...
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
#
# 162th 9 Queens Problem Result:
# ....Q....
# .Q.......
# ........Q
# .....Q...
# ..Q......
# ......Q..
# ...Q.....
# Q........
# .......Q.
#
# 163th 9 Queens Problem Result:
# ....Q....
# ..Q......
# Q........
# .....Q...
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# .......Q.
#
# 164th 9 Queens Problem Result:
# ....Q....
# ..Q......
# Q........
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ......Q..
# ........Q
#
# 165th 9 Queens Problem Result:
# ....Q....
# ..Q......
# Q........
# ......Q..
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
# ........Q
#
# 166th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .....Q...
# ........Q
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ......Q..
#
# 167th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .....Q...
# ........Q
# ......Q..
# Q........
# ...Q.....
# .Q.......
# .......Q.
#
# 168th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .....Q...
# ........Q
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
#
# 169th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .....Q...
# ........Q
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .Q.......
#
# 170th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .......Q.
# ...Q.....
# .Q.......
# ........Q
# .....Q...
# Q........
# ......Q..
#
# 171th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# .....Q...
# Q........
#
# 172th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
# Q........
# ...Q.....
# ......Q..
#
# 173th 9 Queens Problem Result:
# ....Q....
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
# ......Q..
# Q........
# ...Q.....
#
# 174th 9 Queens Problem Result:
# ....Q....
# ..Q......
# ........Q
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# Q........
# ......Q..
#
# 175th 9 Queens Problem Result:
# ....Q....
# ..Q......
# ........Q
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# Q........
# ......Q..
#
# 176th 9 Queens Problem Result:
# ....Q....
# ......Q..
# Q........
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ........Q
# ..Q......
#
# 177th 9 Queens Problem Result:
# ....Q....
# ......Q..
# Q........
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ........Q
# ..Q......
#
# 178th 9 Queens Problem Result:
# ....Q....
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
# ..Q......
# ........Q
# .....Q...
#
# 179th 9 Queens Problem Result:
# ....Q....
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
# ........Q
# .....Q...
# ..Q......
#
# 180th 9 Queens Problem Result:
# ....Q....
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# Q........
# .......Q.
# ...Q.....
# ........Q
#
# 181th 9 Queens Problem Result:
# ....Q....
# ......Q..
# .Q.......
# .....Q...
# .......Q.
# Q........
# ...Q.....
# ........Q
# ..Q......
#
# 182th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .....Q...
# ........Q
# .Q.......
# .......Q.
#
# 183th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
#
# 184th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ...Q.....
# Q........
# ..Q......
# ........Q
# .....Q...
# .......Q.
# .Q.......
#
# 185th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .Q.......
# ........Q
# .....Q...
# ..Q......
#
# 186th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ........Q
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
# Q........
#
# 187th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ..Q......
# Q........
#
# 188th 9 Queens Problem Result:
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .......Q.
# Q........
# ..Q......
# .....Q...
# .Q.......
#
# 189th 9 Queens Problem Result:
# ....Q....
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ..Q......
# .....Q...
# ........Q
# .Q.......
#
# 190th 9 Queens Problem Result:
# ....Q....
# .......Q.
# Q........
# ........Q
# ...Q.....
# .Q.......
# ......Q..
# ..Q......
# .....Q...
#
# 191th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
# Q........
# ........Q
# ...Q.....
# .....Q...
#
# 192th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
# .....Q...
# ........Q
# Q........
# ...Q.....
#
# 193th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .Q.......
# ........Q
# ..Q......
# Q........
# ......Q..
# ...Q.....
# .....Q...
#
# 194th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .Q.......
# ........Q
# .....Q...
# ..Q......
# Q........
# ...Q.....
# ......Q..
#
# 195th 9 Queens Problem Result:
# ....Q....
# .......Q.
# ...Q.....
# Q........
# ..Q......
# .....Q...
# ........Q
# ......Q..
# .Q.......
#
# 196th 9 Queens Problem Result:
# ....Q....
# .......Q.
# ...Q.....
# Q........
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# ........Q
#
# 197th 9 Queens Problem Result:
# ....Q....
# .......Q.
# ...Q.....
# ........Q
# ......Q..
# ..Q......
# Q........
# .....Q...
# .Q.......
#
# 198th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .....Q...
# Q........
# ..Q......
# ......Q..
# ........Q
# ...Q.....
# .Q.......
#
# 199th 9 Queens Problem Result:
# ....Q....
# .......Q.
# .....Q...
# ........Q
# ..Q......
# Q........
# ......Q..
# ...Q.....
# .Q.......
#
# 200th 9 Queens Problem Result:
# ....Q....
# ........Q
# .Q.......
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .....Q...
# Q........
#
# 201th 9 Queens Problem Result:
# ....Q....
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# Q........
# ...Q.....
# ......Q..
#
# 202th 9 Queens Problem Result:
# ....Q....
# ........Q
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ......Q..
# Q........
# ..Q......
#
# 203th 9 Queens Problem Result:
# .....Q...
# Q........
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
#
# 204th 9 Queens Problem Result:
# .....Q...
# Q........
# ....Q....
# ......Q..
# ........Q
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
#
# 205th 9 Queens Problem Result:
# .....Q...
# Q........
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
#
# 206th 9 Queens Problem Result:
# .....Q...
# Q........
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ....Q....
# ........Q
# .Q.......
#
# 207th 9 Queens Problem Result:
# .....Q...
# .Q.......
# ....Q....
# ......Q..
# ........Q
# ..Q......
# .......Q.
# ...Q.....
# Q........
#
# 208th 9 Queens Problem Result:
# .....Q...
# .Q.......
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .......Q.
# Q........
# ..Q......
#
# 209th 9 Queens Problem Result:
# .....Q...
# .Q.......
# ........Q
# ....Q....
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# Q........
#
# 210th 9 Queens Problem Result:
# .....Q...
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# ....Q....
# .......Q.
#
# 211th 9 Queens Problem Result:
# .....Q...
# ..Q......
# Q........
# .......Q.
# ...Q.....
# ........Q
# ......Q..
# ....Q....
# .Q.......
#
# 212th 9 Queens Problem Result:
# .....Q...
# ..Q......
# Q........
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ...Q.....
#
# 213th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ....Q....
# .......Q.
# Q........
# ...Q.....
# .Q.......
# ......Q..
# ........Q
#
# 214th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ....Q....
# .......Q.
# Q........
# ........Q
# ...Q.....
# .Q.......
# ......Q..
#
# 215th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ....Q....
# .......Q.
# Q........
# ........Q
# ......Q..
# .Q.......
# ...Q.....
#
# 216th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# ...Q.....
# .......Q.
# Q........
# ....Q....
# ........Q
#
# 217th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# ...Q.....
# ........Q
# Q........
# .......Q.
# ....Q....
#
# 218th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
# Q........
# ...Q.....
# ........Q
#
# 219th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ......Q..
# ...Q.....
# Q........
# ........Q
# .Q.......
# ....Q....
# .......Q.
#
# 220th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ........Q
# .Q.......
# ....Q....
# .......Q.
# Q........
# ......Q..
# ...Q.....
#
# 221th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ........Q
# ...Q.....
# Q........
# .......Q.
# .Q.......
# ....Q....
# ......Q..
#
# 222th 9 Queens Problem Result:
# .....Q...
# ..Q......
# ........Q
# ......Q..
# Q........
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
#
# 223th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# Q........
# ......Q..
# ........Q
# .Q.......
# .......Q.
# ....Q....
# ..Q......
#
# 224th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# .Q.......
# ......Q..
# ........Q
# ..Q......
# ....Q....
# .......Q.
# Q........
#
# 225th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ..Q......
# ........Q
# ......Q..
# ....Q....
# Q........
#
# 226th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ....Q....
# ..Q......
# Q........
# ........Q
# ......Q..
#
# 227th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ....Q....
# ........Q
# Q........
# ..Q......
# ......Q..
#
# 228th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ......Q..
# Q........
# ..Q......
# ........Q
# .Q.......
# .......Q.
# ....Q....
#
# 229th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ......Q..
# Q........
# .......Q.
# .Q.......
# ....Q....
# ..Q......
# ........Q
#
# 230th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ......Q..
# Q........
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ..Q......
#
# 231th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ........Q
# Q........
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
#
# 232th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ........Q
# Q........
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
#
# 233th 9 Queens Problem Result:
# .....Q...
# ...Q.....
# ........Q
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
# Q........
#
# 234th 9 Queens Problem Result:
# .....Q...
# .......Q.
# Q........
# ....Q....
# ........Q
# .Q.......
# ...Q.....
# ......Q..
# ..Q......
#
# 235th 9 Queens Problem Result:
# .....Q...
# .......Q.
# Q........
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# ....Q....
# ..Q......
#
# 236th 9 Queens Problem Result:
# .....Q...
# .......Q.
# .Q.......
# ......Q..
# Q........
# ..Q......
# ....Q....
# ........Q
# ...Q.....
#
# 237th 9 Queens Problem Result:
# .....Q...
# .......Q.
# ..Q......
# Q........
# ........Q
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
#
# 238th 9 Queens Problem Result:
# .....Q...
# .......Q.
# ..Q......
# Q........
# ........Q
# ....Q....
# .Q.......
# ...Q.....
# ......Q..
#
# 239th 9 Queens Problem Result:
# .....Q...
# .......Q.
# ..Q......
# ......Q..
# ........Q
# .Q.......
# ....Q....
# Q........
# ...Q.....
#
# 240th 9 Queens Problem Result:
# .....Q...
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# Q........
# ..Q......
#
# 241th 9 Queens Problem Result:
# .....Q...
# ........Q
# Q........
# ...Q.....
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
#
# 242th 9 Queens Problem Result:
# .....Q...
# ........Q
# ..Q......
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ....Q....
#
# 243th 9 Queens Problem Result:
# .....Q...
# ........Q
# ....Q....
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ..Q......
#
# 244th 9 Queens Problem Result:
# .....Q...
# ........Q
# ....Q....
# .Q.......
# .......Q.
# ..Q......
# ......Q..
# ...Q.....
# Q........
#
# 245th 9 Queens Problem Result:
# .....Q...
# ........Q
# ....Q....
# .......Q.
# Q........
# ..Q......
# ......Q..
# .Q.......
# ...Q.....
#
# 246th 9 Queens Problem Result:
# .....Q...
# ........Q
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .Q.......
# ....Q....
# ..Q......
#
# 247th 9 Queens Problem Result:
# ......Q..
# Q........
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# ........Q
# ..Q......
# ....Q....
#
# 248th 9 Queens Problem Result:
# ......Q..
# Q........
# ...Q.....
# .....Q...
# ........Q
# ..Q......
# ....Q....
# .......Q.
# .Q.......
#
# 249th 9 Queens Problem Result:
# ......Q..
# Q........
# ...Q.....
# .......Q.
# ....Q....
# ..Q......
# ........Q
# .....Q...
# .Q.......
#
# 250th 9 Queens Problem Result:
# ......Q..
# Q........
# .....Q...
# .Q.......
# ....Q....
# .......Q.
# ...Q.....
# ........Q
# ..Q......
#
# 251th 9 Queens Problem Result:
# ......Q..
# Q........
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ........Q
# ..Q......
# ....Q....
#
# 252th 9 Queens Problem Result:
# ......Q..
# Q........
# .....Q...
# ........Q
# .Q.......
# ...Q.....
# .......Q.
# ..Q......
# ....Q....
#
# 253th 9 Queens Problem Result:
# ......Q..
# Q........
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ..Q......
# .....Q...
# ...Q.....
#
# 254th 9 Queens Problem Result:
# ......Q..
# .Q.......
# ...Q.....
# Q........
# .......Q.
# ....Q....
# ........Q
# .....Q...
# ..Q......
#
# 255th 9 Queens Problem Result:
# ......Q..
# .Q.......
# ...Q.....
# .....Q...
# Q........
# ........Q
# ....Q....
# ..Q......
# .......Q.
#
# 256th 9 Queens Problem Result:
# ......Q..
# .Q.......
# ...Q.....
# ........Q
# Q........
# .......Q.
# ....Q....
# ..Q......
# .....Q...
#
# 257th 9 Queens Problem Result:
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# Q........
# .......Q.
# ....Q....
# ........Q
# ...Q.....
#
# 258th 9 Queens Problem Result:
# ......Q..
# .Q.......
# .......Q.
# .....Q...
# Q........
# ..Q......
# ....Q....
# ........Q
# ...Q.....
#
# 259th 9 Queens Problem Result:
# ......Q..
# ..Q......
# Q........
# .....Q...
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# ........Q
#
# 260th 9 Queens Problem Result:
# ......Q..
# ..Q......
# Q........
# ........Q
# ....Q....
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
#
# 261th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .....Q...
# .Q.......
# ....Q....
# Q........
# ........Q
# ...Q.....
# .......Q.
#
# 262th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .....Q...
# .......Q.
# Q........
# ...Q.....
# ........Q
# ....Q....
# .Q.......
#
# 263th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .....Q...
# .......Q.
# Q........
# ....Q....
# ........Q
# .Q.......
# ...Q.....
#
# 264th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
# ........Q
# ....Q....
# Q........
#
# 265th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
# Q........
# ........Q
# ...Q.....
# .....Q...
#
# 266th 9 Queens Problem Result:
# ......Q..
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
# ....Q....
# Q........
# ...Q.....
#
# 267th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .....Q...
# ........Q
# .Q.......
# .......Q.
# ....Q....
#
# 268th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .......Q.
# .....Q...
# .Q.......
# ........Q
# ....Q....
#
# 269th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# ..Q......
# ........Q
# .....Q...
# .......Q.
# ....Q....
# .Q.......
#
# 270th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# ....Q....
# .Q.......
# ........Q
# .....Q...
# .......Q.
# ..Q......
#
# 271th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .Q.......
# ........Q
# .....Q...
# ..Q......
# ....Q....
#
# 272th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# .......Q.
# ....Q....
# ..Q......
# .....Q...
# ........Q
# .Q.......
#
# 273th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# Q........
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# ....Q....
#
# 274th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
# Q........
# ..Q......
# .....Q...
# ........Q
#
# 275th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .Q.......
# ....Q....
# ........Q
# Q........
# ..Q......
# .......Q.
# .....Q...
#
# 276th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# Q........
# ..Q......
# ....Q....
# ........Q
#
# 277th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# ....Q....
# Q........
# .......Q.
# .....Q...
# ..Q......
#
# 278th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .Q.......
# ........Q
# .....Q...
# ..Q......
# ....Q....
# .......Q.
# Q........
#
# 279th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .......Q.
# Q........
# ....Q....
# ........Q
# .Q.......
# .....Q...
# ..Q......
#
# 280th 9 Queens Problem Result:
# ......Q..
# ...Q.....
# .......Q.
# ..Q......
# ........Q
# .....Q...
# .Q.......
# ....Q....
# Q........
#
# 281th 9 Queens Problem Result:
# ......Q..
# ....Q....
# Q........
# .....Q...
# ........Q
# ..Q......
# .......Q.
# ...Q.....
# .Q.......
#
# 282th 9 Queens Problem Result:
# ......Q..
# ....Q....
# Q........
# .......Q.
# .....Q...
# ..Q......
# ........Q
# .Q.......
# ...Q.....
#
# 283th 9 Queens Problem Result:
# ......Q..
# ....Q....
# .Q.......
# .......Q.
# Q........
# ..Q......
# ........Q
# .....Q...
# ...Q.....
#
# 284th 9 Queens Problem Result:
# ......Q..
# ....Q....
# .Q.......
# .......Q.
# Q........
# ...Q.....
# ........Q
# ..Q......
# .....Q...
#
# 285th 9 Queens Problem Result:
# ......Q..
# ....Q....
# ..Q......
# ........Q
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# Q........
#
# 286th 9 Queens Problem Result:
# ......Q..
# ....Q....
# .......Q.
# .Q.......
# ........Q
# ..Q......
# .....Q...
# ...Q.....
# Q........
#
# 287th 9 Queens Problem Result:
# ......Q..
# ....Q....
# .......Q.
# .Q.......
# ........Q
# .....Q...
# ..Q......
# Q........
# ...Q.....
#
# 288th 9 Queens Problem Result:
# ......Q..
# ........Q
# Q........
# ..Q......
# ....Q....
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
#
# 289th 9 Queens Problem Result:
# ......Q..
# ........Q
# .Q.......
# .....Q...
# Q........
# ..Q......
# ....Q....
# .......Q.
# ...Q.....
#
# 290th 9 Queens Problem Result:
# ......Q..
# ........Q
# ..Q......
# ....Q....
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
# Q........
#
# 291th 9 Queens Problem Result:
# ......Q..
# ........Q
# ..Q......
# .......Q.
# .Q.......
# ...Q.....
# .....Q...
# Q........
# ....Q....
#
# 292th 9 Queens Problem Result:
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# Q........
# ..Q......
#
# 293th 9 Queens Problem Result:
# ......Q..
# ........Q
# .....Q...
# ..Q......
# Q........
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
#
# 294th 9 Queens Problem Result:
# .......Q.
# Q........
# ...Q.....
# .....Q...
# ..Q......
# ........Q
# ......Q..
# ....Q....
# .Q.......
#
# 295th 9 Queens Problem Result:
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ..Q......
# .....Q...
# ........Q
# .Q.......
# ....Q....
#
# 296th 9 Queens Problem Result:
# .......Q.
# Q........
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
# ........Q
# .....Q...
# ..Q......
#
# 297th 9 Queens Problem Result:
# .......Q.
# Q........
# ....Q....
# ......Q..
# .Q.......
# .....Q...
# ..Q......
# ........Q
# ...Q.....
#
# 298th 9 Queens Problem Result:
# .......Q.
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ........Q
# .....Q...
# ..Q......
# ....Q....
#
# 299th 9 Queens Problem Result:
# .......Q.
# .Q.......
# ....Q....
# ......Q..
# Q........
# ...Q.....
# .....Q...
# ........Q
# ..Q......
#
# 300th 9 Queens Problem Result:
# .......Q.
# .Q.......
# ........Q
# .....Q...
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ....Q....
#
# 301th 9 Queens Problem Result:
# .......Q.
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ........Q
# .....Q...
# .Q.......
# ....Q....
#
# 302th 9 Queens Problem Result:
# .......Q.
# ..Q......
# ....Q....
# .Q.......
# ........Q
# .....Q...
# ...Q.....
# ......Q..
# Q........
#
# 303th 9 Queens Problem Result:
# .......Q.
# ..Q......
# ....Q....
# ........Q
# Q........
# .....Q...
# ...Q.....
# .Q.......
# ......Q..
#
# 304th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# Q........
# ......Q..
# ....Q....
# .Q.......
# .....Q...
# ........Q
# ..Q......
#
# 305th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# ......Q..
# ........Q
# .Q.......
# .....Q...
# Q........
# ..Q......
# ....Q....
#
# 306th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# ........Q
# Q........
# ....Q....
# .Q.......
# .....Q...
# ..Q......
# ......Q..
#
# 307th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# ........Q
# ..Q......
# ....Q....
# ......Q..
# Q........
# .....Q...
# .Q.......
#
# 308th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# ........Q
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# ....Q....
# Q........
#
# 309th 9 Queens Problem Result:
# .......Q.
# ...Q.....
# ........Q
# ......Q..
# ..Q......
# Q........
# .....Q...
# .Q.......
# ....Q....
#
# 310th 9 Queens Problem Result:
# .......Q.
# ....Q....
# Q........
# .....Q...
# ........Q
# .Q.......
# ...Q.....
# ......Q..
# ..Q......
#
# 311th 9 Queens Problem Result:
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ........Q
# ..Q......
# .....Q...
#
# 312th 9 Queens Problem Result:
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ........Q
# .....Q...
# ..Q......
#
# 313th 9 Queens Problem Result:
# .......Q.
# ....Q....
# .Q.......
# ........Q
# Q........
# ...Q.....
# ......Q..
# ..Q......
# .....Q...
#
# 314th 9 Queens Problem Result:
# .......Q.
# ....Q....
# .Q.......
# ........Q
# ......Q..
# ...Q.....
# Q........
# ..Q......
# .....Q...
#
# 315th 9 Queens Problem Result:
# .......Q.
# ....Q....
# ..Q......
# Q........
# .....Q...
# .Q.......
# ........Q
# ......Q..
# ...Q.....
#
# 316th 9 Queens Problem Result:
# .......Q.
# ....Q....
# ..Q......
# Q........
# ......Q..
# ...Q.....
# .....Q...
# ........Q
# .Q.......
#
# 317th 9 Queens Problem Result:
# .......Q.
# ....Q....
# ..Q......
# .....Q...
# ........Q
# ......Q..
# Q........
# ...Q.....
# .Q.......
#
# 318th 9 Queens Problem Result:
# .......Q.
# ....Q....
# ..Q......
# ........Q
# ......Q..
# .Q.......
# ...Q.....
# .....Q...
# Q........
#
# 319th 9 Queens Problem Result:
# .......Q.
# .....Q...
# Q........
# ..Q......
# ....Q....
# ......Q..
# ........Q
# ...Q.....
# .Q.......
#
# 320th 9 Queens Problem Result:
# .......Q.
# .....Q...
# Q........
# ..Q......
# ......Q..
# ........Q
# ...Q.....
# .Q.......
# ....Q....
#
# 321th 9 Queens Problem Result:
# .......Q.
# .....Q...
# .Q.......
# ......Q..
# Q........
# ...Q.....
# ........Q
# ....Q....
# ..Q......
#
# 322th 9 Queens Problem Result:
# .......Q.
# .....Q...
# ..Q......
# ........Q
# ......Q..
# Q........
# ...Q.....
# .Q.......
# ....Q....
#
# 323th 9 Queens Problem Result:
# .......Q.
# .....Q...
# ........Q
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ....Q....
# .Q.......
#
# 324th 9 Queens Problem Result:
# ........Q
# .Q.......
# ....Q....
# ......Q..
# Q........
# ..Q......
# .......Q.
# .....Q...
# ...Q.....
#
# 325th 9 Queens Problem Result:
# ........Q
# .Q.......
# ....Q....
# ......Q..
# ...Q.....
# Q........
# .......Q.
# .....Q...
# ..Q......
#
# 326th 9 Queens Problem Result:
# ........Q
# .Q.......
# .....Q...
# .......Q.
# ..Q......
# Q........
# ...Q.....
# ......Q..
# ....Q....
#
# 327th 9 Queens Problem Result:
# ........Q
# ..Q......
# ....Q....
# .Q.......
# .......Q.
# Q........
# ......Q..
# ...Q.....
# .....Q...
#
# 328th 9 Queens Problem Result:
# ........Q
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# Q........
# ...Q.....
# .......Q.
# ....Q....
#
# 329th 9 Queens Problem Result:
# ........Q
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# ....Q....
# Q........
# .......Q.
# ...Q.....
#
# 330th 9 Queens Problem Result:
# ........Q
# ..Q......
# .....Q...
# ...Q.....
# Q........
# .......Q.
# ....Q....
# ......Q..
# .Q.......
#
# 331th 9 Queens Problem Result:
# ........Q
# ...Q.....
# Q........
# ....Q....
# .......Q.
# .Q.......
# ......Q..
# ..Q......
# .....Q...
#
# 332th 9 Queens Problem Result:
# ........Q
# ...Q.....
# .Q.......
# ....Q....
# .......Q.
# .....Q...
# Q........
# ..Q......
# ......Q..
#
# 333th 9 Queens Problem Result:
# ........Q
# ...Q.....
# .Q.......
# ......Q..
# ..Q......
# .....Q...
# .......Q.
# Q........
# ....Q....
#
# 334th 9 Queens Problem Result:
# ........Q
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ......Q..
# Q........
# ..Q......
# ....Q....
#
# 335th 9 Queens Problem Result:
# ........Q
# ...Q.....
# .....Q...
# .......Q.
# ..Q......
# Q........
# ......Q..
# ....Q....
# .Q.......
#
# 336th 9 Queens Problem Result:
# ........Q
# ...Q.....
# .......Q.
# Q........
# ..Q......
# .....Q...
# .Q.......
# ......Q..
# ....Q....
#
# 337th 9 Queens Problem Result:
# ........Q
# ....Q....
# Q........
# ...Q.....
# .....Q...
# .......Q.
# .Q.......
# ......Q..
# ..Q......
#
# 338th 9 Queens Problem Result:
# ........Q
# ....Q....
# Q........
# .......Q.
# ...Q.....
# .Q.......
# ......Q..
# ..Q......
# .....Q...
#
# 339th 9 Queens Problem Result:
# ........Q
# ....Q....
# ..Q......
# Q........
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# ......Q..
#
# 340th 9 Queens Problem Result:
# ........Q
# ....Q....
# ..Q......
# Q........
# ......Q..
# .Q.......
# .......Q.
# .....Q...
# ...Q.....
#
# 341th 9 Queens Problem Result:
# ........Q
# ....Q....
# ..Q......
# .......Q.
# ...Q.....
# ......Q..
# Q........
# .....Q...
# .Q.......
#
# 342th 9 Queens Problem Result:
# ........Q
# ....Q....
# .......Q.
# ...Q.....
# Q........
# ......Q..
# .Q.......
# .....Q...
# ..Q......
#
# 343th 9 Queens Problem Result:
# ........Q
# .....Q...
# .Q.......
# ......Q..
# Q........
# ..Q......
# ....Q....
# .......Q.
# ...Q.....
#
# 344th 9 Queens Problem Result:
# ........Q
# .....Q...
# ..Q......
# Q........
# .......Q.
# ....Q....
# .Q.......
# ...Q.....
# ......Q..
#
# 345th 9 Queens Problem Result:
# ........Q
# .....Q...
# ..Q......
# ......Q..
# .Q.......
# .......Q.
# ....Q....
# Q........
# ...Q.....
#
# 346th 9 Queens Problem Result:
# ........Q
# .....Q...
# ...Q.....
# .Q.......
# .......Q.
# ....Q....
# ......Q..
# Q........
# ..Q......
#
# 347th 9 Queens Problem Result:
# ........Q
# .....Q...
# ...Q.....
# ......Q..
# Q........
# .......Q.
# .Q.......
# ....Q....
# ..Q......
#
# 348th 9 Queens Problem Result:
# ........Q
# .....Q...
# .......Q.
# .Q.......
# ...Q.....
# Q........
# ......Q..
# ....Q....
# ..Q......
#
# 349th 9 Queens Problem Result:
# ........Q
# ......Q..
# .Q.......
# ...Q.....
# Q........
# .......Q.
# ....Q....
# ..Q......
# .....Q...
#
# 350th 9 Queens Problem Result:
# ........Q
# ......Q..
# ..Q......
# .......Q.
# .Q.......
# ....Q....
# Q........
# .....Q...
# ...Q.....
#
# 351th 9 Queens Problem Result:
# ........Q
# ......Q..
# ...Q.....
# .Q.......
# .......Q.
# .....Q...
# Q........
# ..Q......
# ....Q....
#
# ================================= 9 Queens Problem Result =================================
# ================================= 9 Queens Problem Result =================================

# %% [markdown]
# * Note : 上述輸出格式為 ===...=== + N Queen 問題的所有解(用`i`th 標示第幾個解) + ===...===，其中像是 n = 2 和 n = 3 這類是沒有解的，另外，一些編譯器有設定限制輸出的量，可能需要更改設定才能看到完整所有輸出，或是採用下方方式輸出成檔案。

# %%
for n in range(1, 10):
    solution = Solution()
    result = solution.solveNQueens(n)
    solution.write_result_to_file(file_name=f"output_{n}_queens_result")

# %% [markdown]
# ### 轉換成 FEN 格式

# %%
from typing import *

def convert_to_fen(board: List[str]) -> str:    
    """
    將 N-Queens 的棋盤輸出轉換為 FEN 格式，適用於 Lichess Editor。
    
    :param board: List[str]，表示 N-Queens 棋盤的解，每行是一個字串，'Q' 表示皇后，'.' 表示空格。
    :return: str，FEN 格式的棋盤表示。
    """
    fen_rows = []
    for row in board:
        empty_count = 0
        fen_row = ""
        for cell in row:
            if cell == '.':
                empty_count += 1  # 計算連續的空格數
            else:
                if empty_count > 0:
                    fen_row += str(empty_count)  # 將空格數轉為數字
                    empty_count = 0
                fen_row += 'Q'  # 'Q' 表示皇后
        if empty_count > 0:
            fen_row += str(empty_count)  # 處理行末的空格
        fen_rows.append(fen_row)
    return "/".join(fen_rows)  # 使用 '/' 分隔每一行

# %% [markdown]
# ### 傳送 FEN 格式到 lichess editor 並獲取截圖

# %%
import requests

def get_lichess_chessboard_screenshot(fen_format: str, save_dir: str = "./screenshots/", file_name: str = "screenshot.gif"):
    screenshot_url = "https://lichess1.org/export/fen.gif?fen=" + fen_format
    response = requests.get(screenshot_url)

    if response.status_code == 200:
        os.makedirs(save_dir, exist_ok=True)
        with open(save_dir + f"{file_name}.gif", "wb") as f:
            f.write(response.content)
        print(f"Download {file_name}.gif successfully")
    else:
        print("Failed to download, HTTP status code: ", response.status_code)

# %% [markdown]
# ### 一次用 1 - 9 Queens 問題對 lichess 發送 request

# %%
for n in range(1, 10):
    solution = Solution()
    result = solution.solveNQueens(n)
    for count_sol in range(len(result)):
        fen_format = convert_to_fen(result[count_sol])
        get_lichess_chessboard_screenshot(fen_format=fen_format, save_dir=f"./screenshots/{n}_queens_problem/", file_name=f"screenshot_{count_sol}th_solution")
# Out:
# Failed to download, HTTP status code:  429
# Failed to download, HTTP status code:  429
# Failed to download, HTTP status code:  429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 18
#      16 fen_format = convert_to_fen(result[count_sol])
#      17 get_lichess_chessboard_screenshot(fen_format=fen_format, save_dir=f"./screenshots/{n}_queens_problem/", file_name=f"screenshot_{count_sol}th_solution")
# ---> 18 time.sleep(2)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 嘗試每兩秒發一次 request 並只針對 8 Queens 問題抓取截圖

# %%
import time

# The above will make tons of requests to the lichess which will lead us blocked by them...
# and we may also need to pause for 2 seconds during the time while we fetching the screenshot
n = 8
solution = Solution()
result = solution.solveNQueens(n)
print(f"Start to fetch {len(result)} screenshots from lichess editor...")
for count_sol in range(len(result)):
    fen_format = convert_to_fen(result[count_sol])
    get_lichess_chessboard_screenshot(fen_format=fen_format, save_dir=f"./screenshots/{n}_queens_problem/", file_name=f"screenshot_{count_sol}th_solution")
    time.sleep(2)
# Out:
# Download screenshot_0th_solution.gif successfully
# Download screenshot_1th_solution.gif successfully
# Download screenshot_2th_solution.gif successfully
# Download screenshot_3th_solution.gif successfully
# Download screenshot_4th_solution.gif successfully
# Download screenshot_5th_solution.gif successfully
# Download screenshot_6th_solution.gif successfully
# Download screenshot_7th_solution.gif successfully
# Download screenshot_8th_solution.gif successfully
# Download screenshot_9th_solution.gif successfully
# Download screenshot_10th_solution.gif successfully
# Download screenshot_11th_solution.gif successfully
# Download screenshot_12th_solution.gif successfully
# Download screenshot_13th_solution.gif successfully
# Download screenshot_14th_solution.gif successfully
# Download screenshot_15th_solution.gif successfully
# Download screenshot_16th_solution.gif successfully
# Download screenshot_17th_solution.gif successfully
# Download screenshot_18th_solution.gif successfully
# Download screenshot_19th_solution.gif successfully
# Download screenshot_20th_solution.gif successfully
# Download screenshot_21th_solution.gif successfully
# Download screenshot_22th_solution.gif successfully
# Download screenshot_23th_solution.gif successfully
# Download screenshot_24th_solution.gif successfully
# Download screenshot_25th_solution.gif successfully
# Download screenshot_26th_solution.gif successfully
# Download screenshot_27th_solution.gif successfully
# Download screenshot_28th_solution.gif successfully
# Download screenshot_29th_solution.gif successfully
# Download screenshot_30th_solution.gif successfully
# Download screenshot_31th_solution.gif successfully
# Download screenshot_32th_solution.gif successfully
# Download screenshot_33th_solution.gif successfully
# Download screenshot_34th_solution.gif successfully
# Download screenshot_35th_solution.gif successfully
# Download screenshot_36th_solution.gif successfully
# Download screenshot_37th_solution.gif successfully
# Download screenshot_38th_solution.gif successfully
# Download screenshot_39th_solution.gif successfully
# Download screenshot_40th_solution.gif successfully
# Download screenshot_41th_solution.gif successfully
# Download screenshot_42th_solution.gif successfully
# Download screenshot_43th_solution.gif successfully
# Download screenshot_44th_solution.gif successfully
# Download screenshot_45th_solution.gif successfully
# Download screenshot_46th_solution.gif successfully
# Download screenshot_47th_solution.gif successfully
# Download screenshot_48th_solution.gif successfully
# Download screenshot_49th_solution.gif successfully
# Download screenshot_50th_solution.gif successfully
# Download screenshot_51th_solution.gif successfully
# Download screenshot_52th_solution.gif successfully
# Download screenshot_53th_solution.gif successfully
# Download screenshot_54th_solution.gif successfully
# Download screenshot_55th_solution.gif successfully
# Download screenshot_56th_solution.gif successfully
# Download screenshot_57th_solution.gif successfully
# Download screenshot_58th_solution.gif successfully
# Download screenshot_59th_solution.gif successfully
# Download screenshot_60th_solution.gif successfully
# Download screenshot_61th_solution.gif successfully
# Download screenshot_62th_solution.gif successfully
# Download screenshot_63th_solution.gif successfully
# Download screenshot_64th_solution.gif successfully
# Download screenshot_65th_solution.gif successfully
# Download screenshot_66th_solution.gif successfully
# Download screenshot_67th_solution.gif successfully
# Download screenshot_68th_solution.gif successfully
# Download screenshot_69th_solution.gif successfully
# Download screenshot_70th_solution.gif successfully
# Download screenshot_71th_solution.gif successfully
# Download screenshot_72th_solution.gif successfully
# Download screenshot_73th_solution.gif successfully
# Download screenshot_74th_solution.gif successfully
# Download screenshot_75th_solution.gif successfully
# Download screenshot_76th_solution.gif successfully
# Download screenshot_77th_solution.gif successfully
# Download screenshot_78th_solution.gif successfully
# Download screenshot_79th_solution.gif successfully
# Download screenshot_80th_solution.gif successfully
# Download screenshot_81th_solution.gif successfully
# Download screenshot_82th_solution.gif successfully
# Download screenshot_83th_solution.gif successfully
# Download screenshot_84th_solution.gif successfully
# Download screenshot_85th_solution.gif successfully
# Download screenshot_86th_solution.gif successfully
# Download screenshot_87th_solution.gif successfully
# Download screenshot_88th_solution.gif successfully
# Download screenshot_89th_solution.gif successfully
# Download screenshot_90th_solution.gif successfully
# Download screenshot_91th_solution.gif successfully

# %% [markdown]
# ## Generic Algorithm for 8 Queen Problem
#
# * 參考自 **Github**：https://github.com/alirezaeftekhari/8-queens-genetic-algorithm

# %%
import random  # 引入隨機模組，用於生成隨機數

# 函數：顯示解決方案
def view(li, index):
    print()
    print(f"Solution number {index + 1}: ", end='')  # 顯示解決方案編號
    print(li)  # 顯示解決方案的數字表示
    print()

    # 以棋盤形式顯示解決方案
    for i in range(8):
        x = li[i] - 1  # 獲取皇后的位置
        for j in range(8):
            if j == x:
                print('[Q]', end='')  # 皇后的位置
            else:
                print('[ ]', end='')  # 空格
        print()
    
    print()

# 函數：計算啟發值（Huristic），即每個皇后與其他皇后的衝突數量
def getHuristic(instance):
    huristic = []  # 儲存每個皇后的衝突數量
    for i in range(len(instance)):
        j = i - 1
        huristic.append(0)  # 初始化當前皇后的衝突數量為 0
        # 檢查當前皇后與左側皇后的衝突
        while j >= 0:
            if instance[i] == instance[j] or (abs(instance[i] - instance[j]) == abs(i - j)):
                huristic[i] += 1
            j -= 1
        # 檢查當前皇后與右側皇后的衝突
        j = i + 1
        while j < len(instance):
            if instance[i] == instance[j] or (abs(instance[i] - instance[j]) == abs(i - j)):
                huristic[i] += 1
            j += 1
    return huristic

# 函數：計算適應值（Fitness），即無衝突的皇后對數
def getFitness(instance):
    clashes = 0  # 計算衝突數量
    # 檢查是否有皇后在同一列
    for i in range(len(instance) - 1):
        for j in range(i + 1, len(instance)):
            if instance[i] == instance[j]:
                clashes += 1
    # 檢查是否有皇后在對角線上
    for i in range(len(instance) - 1):
        for j in range(i + 1, len(instance)):
            if abs(instance[j] - instance[i]) == abs(j - i):
                clashes += 1
    return 28 - clashes  # 最大適應值為 28（8 皇后無衝突）

# 函數：生成子代（新棋盤配置）
def buildKid(instance1, instance2, crossOver):
    newInstance = []  # 儲存新棋盤配置
    # 前半部分從父代 1 繼承
    for i in range(crossOver):
        newInstance.append(instance1[random.randint(0, 7)])
    # 後半部分從父代 2 繼承
    for i in range(crossOver, 8):
        newInstance.append(instance2[random.randint(0, 7)])
    return newInstance

# 函數：生成兩個子代
def changeChilds(co):
    global father, mother, child1, child2, crossover
    crossover = co  # 設定交叉點
    child1 = buildKid(father, mother, crossover)  # 生成第一個子代
    child2 = buildKid(mother, father, crossover)  # 生成第二個子代

# 函數：調整子代的基因（棋盤配置）
def changeChromosome(li):
    global crossover, father, mother
    newchange = -1  # 初始化變更標誌
    while newchange != 0:
        newchange = 0
        tmpli = li  # 暫存當前棋盤配置
        getHur = getHuristic(tmpli)  # 計算啟發值
        index = getHur.index(max(getHur))  # 找到衝突最多的皇后
        maxFitness = getFitness(tmpli)  # 計算當前適應值
        # 嘗試調整皇后位置以提高適應值
        for i in range(1, 9):
            tmpli[index] = i
            if getFitness(tmpli) > maxFitness:
                maxFitness = getFitness(tmpli)
                newchange = i
            tmpli = li
        # 如果無法提高適應值，隨機調整重複的皇后位置
        if newchange == 0:
            for i in range(len(li) - 1):
                for j in range(i + 1, len(li)):
                    if li[i] == li[j]:
                        li[j] = random.randint(1, 8)
        else:
            li[index] = newchange  # 更新皇后位置

# 主程式
if __name__ == "__main__":
    numberOfSolutions = int(input())  # 輸入需要的解決方案數量
    
    solutions = []  # 儲存所有解決方案
    crossover = 4  # 設定交叉點
    while len(solutions) < numberOfSolutions:
        father = []  # 初始化父代 1
        mother = []  # 初始化父代 2
        for i in range(8):
            father.append(random.randint(1, 8))  # 隨機生成父代 1 的棋盤配置
            mother.append(random.randint(1, 8))  # 隨機生成父代 2 的棋盤配置
        fitnessFather = getFitness(father)  # 計算父代 1 的適應值
        fitnessMother = getFitness(mother)  # 計算父代 2 的適應值
        # 不斷生成子代直到找到適應值為 28 的解決方案
        while fitnessFather != 28 and fitnessMother != 28:
            changeChilds(crossover)  # 生成子代
            changeChromosome(child1)  # 調整子代 1
            changeChromosome(child2)  # 調整子代 2
            fitnessFather = getFitness(child1)  # 更新父代 1 的適應值
            fitnessMother = getFitness(child2)  # 更新父代 2 的適應值
            father = child1  # 更新父代 1
            mother = child2  # 更新父代 2
            print(father)  # 顯示父代 1 的棋盤配置
            print(mother)  # 顯示父代 2 的棋盤配置
        # 如果找到適應值為 28 的解決方案，加入解決方案列表
        if getFitness(father) == 28:
            if father not in solutions:
                solutions.append(father)
        else:
            if mother not in solutions:
                solutions.append(mother)

    # 顯示所有解決方案
    print("********************** Solutions **********************")
    print(f"The number of solutions you wanted: {numberOfSolutions}")

    for i in range(len(solutions)):
        view(solutions[i], i)  # 以棋盤形式顯示解決方案

    print("*******************************************************")
# Out:
# [8, 2, 5, 7, 4, 1, 7, 6]
# [8, 4, 7, 1, 5, 2, 6, 3]
# [8, 3, 6, 4, 1, 6, 5, 7]
# [2, 7, 3, 8, 2, 5, 1, 6]
# [5, 1, 4, 8, 6, 3, 2, 3]
# [8, 2, 6, 4, 7, 5, 1, 5]
# [8, 3, 7, 4, 1, 5, 2, 6]
# [5, 7, 1, 4, 6, 8, 8, 2]
# [8, 1, 7, 5, 8, 2, 4, 6]
# [8, 5, 2, 4, 1, 7, 1, 3]
# [8, 2, 5, 8, 4, 1, 3, 2]
# [6, 3, 7, 8, 4, 2, 6, 7]
# [1, 6, 4, 2, 8, 8, 3, 7]
# [3, 8, 7, 4, 2, 1, 5, 6]
# [3, 8, 2, 4, 6, 8, 5, 1]
# [8, 2, 5, 3, 1, 7, 4, 6]
# [8, 1, 7, 4, 6, 3, 5, 2]
# [8, 6, 2, 7, 5, 3, 8, 4]
# [8, 2, 3, 7, 6, 1, 5, 8]
# [2, 8, 6, 4, 7, 1, 3, 5]
# [8, 5, 3, 1, 4, 2, 7, 4]
# [4, 8, 1, 6, 1, 5, 7, 3]
# [5, 8, 1, 4, 6, 2, 3, 7]
# [2, 6, 8, 3, 1, 5, 7, 3]
# [7, 8, 4, 2, 1, 3, 6, 1]
# [8, 6, 2, 5, 1, 4, 7, 3]
# [8, 3, 4, 6, 7, 2, 5, 1]
# [7, 8, 1, 5, 8, 6, 4, 2]
# [2, 6, 1, 3, 4, 8, 7, 7]
# [5, 8, 4, 1, 3, 6, 2, 8]
# [8, 2, 3, 7, 4, 1, 8, 5]
# [8, 5, 2, 6, 3, 7, 1, 4]
# [8, 6, 7, 3, 5, 4, 2, 8]
# [8, 3, 7, 2, 6, 5, 1, 4]
# [4, 8, 5, 3, 1, 7, 2, 8]
# [2, 8, 5, 3, 7, 6, 4, 1]
# [2, 5, 7, 1, 3, 8, 6, 7]
# [8, 3, 5, 7, 2, 4, 5, 1]
# [8, 4, 2, 6, 3, 7, 5, 1]
# [4, 8, 1, 5, 1, 2, 7, 7]
# [6, 8, 2, 5, 7, 4, 1, 4]
# [8, 5, 3, 1, 4, 2, 7, 3]
# [8, 2, 6, 1, 5, 7, 2, 3]
# [1, 3, 7, 2, 8, 1, 4, 6]
# [8, 6, 2, 2, 4, 3, 2, 1]
# [8, 6, 3, 2, 7, 1, 4, 3]
# [5, 8, 6, 1, 3, 1, 7, 2]
# [3, 6, 8, 2, 5, 1, 4, 8]
# [7, 2, 4, 8, 6, 5, 3, 7]
# [8, 3, 6, 4, 2, 6, 5, 4]
# [8, 6, 2, 7, 6, 4, 1, 8]
# [5, 3, 8, 7, 2, 4, 1, 3]
# [8, 5, 2, 5, 7, 4, 1, 3]
# [5, 7, 8, 3, 6, 8, 1, 2]
# [8, 7, 5, 1, 3, 6, 6, 2]
# [2, 8, 6, 2, 3, 1, 7, 4]
# [8, 3, 7, 6, 4, 2, 5, 1]
# [3, 5, 2, 6, 8, 7, 2, 1]
# [2, 7, 5, 1, 8, 6, 8, 3]
# [8, 2, 7, 5, 6, 1, 8, 3]
# [4, 8, 3, 1, 6, 4, 2, 3]
# [8, 4, 1, 5, 7, 2, 6, 3]
# [2, 8, 3, 7, 4, 1, 8, 5]
# [8, 5, 6, 1, 3, 7, 2, 4]
# [8, 3, 4, 7, 1, 6, 7, 2]
# [3, 6, 8, 4, 1, 3, 2, 7]
# [8, 1, 7, 3, 6, 2, 1, 5]
# [7, 8, 2, 3, 1, 4, 3, 5]
# [8, 2, 4, 3, 6, 8, 1, 7]
# [2, 6, 8, 7, 4, 1, 3, 5]
# [1, 5, 8, 2, 7, 3, 4, 5]
# [8, 5, 8, 2, 4, 6, 1, 3]
# [8, 5, 7, 1, 4, 2, 8, 6]
# [2, 8, 6, 1, 5, 1, 3, 7]
# [4, 6, 8, 2, 7, 3, 1, 4]
# [5, 7, 1, 4, 8, 2, 6, 1]
# [7, 8, 4, 8, 5, 3, 6, 1]
# [8, 2, 5, 1, 6, 8, 3, 7]
# [8, 7, 4, 1, 2, 5, 3, 6]
# [2, 8, 6, 1, 7, 3, 1, 8]
# [8, 3, 6, 2, 7, 1, 6, 8]
# [8, 3, 2, 6, 1, 1, 7, 4]
# [8, 7, 3, 1, 6, 2, 5, 1]
# [5, 3, 8, 7, 2, 8, 6, 1]
# [8, 4, 2, 7, 5, 3, 3, 6]
# [4, 1, 8, 6, 2, 5, 8, 2]
# [8, 5, 1, 4, 6, 2, 8, 2]
# [2, 7, 1, 4, 8, 4, 3, 1]
# [8, 2, 3, 1, 6, 4, 2, 8]
# [8, 4, 1, 2, 6, 1, 5, 3]
# [8, 6, 3, 2, 4, 7, 1, 2]
# [5, 3, 1, 4, 8, 3, 2, 7]
# [7, 8, 4, 2, 5, 3, 6, 1]
# [8, 5, 2, 1, 3, 7, 4, 7]
# [8, 3, 4, 1, 7, 5, 2, 6]
# [8, 7, 1, 5, 2, 7, 6, 3]
# [6, 8, 5, 7, 1, 3, 6, 5]
# [7, 1, 8, 5, 2, 8, 3, 4]
# [8, 3, 1, 7, 4, 6, 2, 5]
# [3, 8, 4, 7, 1, 6, 3, 6]
# [8, 4, 7, 1, 6, 2, 5, 2]
# [8, 1, 5, 2, 4, 7, 8, 6]
# [8, 5, 2, 4, 8, 7, 3, 6]
# [2, 8, 6, 3, 6, 1, 7, 4]
# [3, 8, 6, 5, 2, 4, 1, 6]
# [6, 8, 2, 4, 3, 5, 7, 1]
# [1, 5, 8, 1, 7, 3, 6, 2]
# [8, 3, 4, 7, 1, 3, 6, 2]
# [5, 8, 6, 1, 4, 2, 3, 2]
# [6, 8, 1, 4, 5, 7, 2, 6]
# [5, 3, 8, 6, 4, 1, 3, 7]
# [1, 6, 8, 7, 2, 4, 6, 5]
# [3, 8, 5, 4, 1, 7, 2, 6]
# [5, 8, 1, 4, 7, 3, 6, 6]
# [4, 7, 8, 3, 1, 6, 3, 5]
# [1, 8, 7, 5, 2, 4, 6, 3]
# [8, 3, 7, 6, 8, 1, 3, 4]
# [6, 8, 7, 2, 3, 2, 1, 8]
# [4, 8, 2, 3, 1, 7, 5, 6]
# [8, 6, 5, 2, 7, 2, 4, 3]
# [8, 6, 3, 1, 5, 4, 2, 7]
# [5, 3, 1, 4, 8, 1, 2, 7]
# [8, 3, 6, 7, 2, 4, 1, 6]
# [5, 8, 2, 6, 3, 1, 7, 4]
# [8, 3, 6, 7, 2, 4, 8, 1]
# [8, 6, 5, 3, 1, 4, 2, 7]
# [1, 4, 8, 1, 2, 7, 3, 6]
# [7, 4, 8, 1, 6, 2, 3, 5]
# [2, 5, 8, 1, 7, 3, 6, 3]
# [5, 8, 8, 6, 2, 3, 1, 3]
# [5, 8, 4, 6, 7, 3, 1, 7]
# [8, 4, 6, 5, 1, 7, 7, 3]
# [8, 7, 2, 6, 3, 1, 4, 1]
# [8, 4, 2, 5, 6, 7, 1, 3]
# [8, 1, 4, 7, 2, 3, 1, 3]
# [6, 2, 7, 8, 4, 1, 6, 3]
# [8, 2, 5, 7, 4, 3, 3, 6]
# [6, 8, 2, 7, 3, 4, 3, 1]
# [8, 4, 6, 3, 5, 2, 6, 1]
# [6, 1, 3, 8, 7, 4, 2, 7]
# [8, 1, 6, 4, 7, 3, 5, 2]
# [8, 2, 7, 6, 3, 1, 5, 4]
# [7, 3, 8, 3, 2, 5, 6, 1]
# [3, 8, 4, 7, 1, 2, 5, 6]
# [1, 8, 6, 5, 7, 2, 4, 6]
# [8, 6, 1, 3, 5, 7, 2, 4]
# [6, 3, 1, 4, 8, 5, 8, 2]
# [3, 1, 4, 8, 8, 6, 2, 5]
# [6, 3, 7, 4, 8, 7, 5, 1]
# [7, 8, 6, 1, 7, 6, 3, 2]
# [8, 7, 3, 1, 5, 7, 6, 2]
# [6, 8, 7, 5, 1, 3, 5, 2]
# [6, 3, 7, 2, 8, 5, 1, 2]
# [2, 7, 8, 6, 8, 3, 1, 5]
# [2, 5, 8, 8, 4, 3, 1, 6]
# [8, 2, 6, 5, 1, 1, 4, 7]
# [5, 2, 8, 3, 7, 2, 1, 1]
# [3, 7, 2, 8, 6, 1, 5, 6]
# [5, 8, 2, 4, 7, 3, 6, 2]
# [8, 6, 1, 3, 5, 3, 2, 4]
# [8, 6, 2, 7, 5, 3, 1, 4]
# [7, 8, 1, 5, 2, 1, 3, 7]
# [6, 8, 1, 5, 7, 2, 4, 6]
# [8, 7, 3, 1, 6, 3, 5, 2]
# [8, 5, 1, 4, 1, 2, 7, 3]
# [8, 4, 5, 3, 6, 5, 7, 8]
# [4, 8, 5, 2, 6, 4, 3, 1]
# [8, 2, 5, 4, 1, 3, 6, 5]
# [6, 4, 1, 8, 5, 2, 7, 3]
# [8, 7, 4, 6, 1, 5, 3, 8]
# [1, 6, 4, 8, 6, 3, 5, 7]
# [8, 2, 7, 5, 3, 7, 6, 4]
# [1, 4, 8, 2, 3, 7, 8, 6]
# [8, 3, 7, 4, 1, 5, 2, 6]
# [8, 3, 1, 7, 5, 4, 2, 5]
# [5, 8, 1, 4, 7, 8, 3, 6]
# [8, 5, 1, 6, 7, 2, 3, 5]
# [8, 1, 4, 2, 7, 3, 5, 2]
# [3, 8, 3, 4, 1, 6, 1, 2]
# [8, 6, 1, 7, 2, 3, 5, 8]
# [8, 6, 3, 1, 5, 7, 2, 8]
# [2, 6, 8, 1, 7, 4, 5, 3]
# [8, 7, 3, 5, 4, 1, 8, 4]
# [8, 6, 4, 1, 4, 8, 3, 6]
# [6, 2, 5, 8, 1, 4, 1, 7]
# [1, 8, 5, 2, 4, 7, 3, 2]
# [8, 5, 7, 1, 3, 8, 2, 4]
# [6, 3, 5, 8, 8, 4, 7, 1]
# [3, 6, 8, 7, 4, 1, 5, 3]
# [3, 6, 2, 5, 8, 1, 7, 1]
# [7, 8, 1, 5, 6, 3, 5, 2]
# [8, 5, 4, 2, 7, 3, 1, 6]
# [2, 8, 5, 1, 4, 3, 7, 1]
# [8, 1, 4, 2, 7, 3, 8, 5]
# [8, 3, 7, 4, 1, 5, 2, 5]
# [8, 2, 5, 3, 1, 4, 6, 7]
# [2, 7, 5, 8, 4, 1, 6, 3]
# [1, 3, 7, 8, 7, 5, 2, 4]
# [8, 7, 3, 1, 6, 5, 4, 2]
# [7, 3, 8, 6, 1, 5, 2, 3]
# [8, 6, 1, 2, 5, 7, 1, 3]
# [8, 5, 1, 7, 1, 3, 6, 2]
# [4, 8, 3, 8, 2, 7, 1, 6]
# [8, 7, 3, 6, 2, 5, 1, 4]
# [6, 3, 1, 4, 7, 5, 8, 2]
# [6, 1, 8, 4, 3, 6, 5, 2]
# [2, 7, 3, 8, 1, 5, 4, 6]
# [8, 6, 4, 2, 7, 1, 3, 5]
# [5, 2, 6, 8, 3, 1, 5, 4]
# [7, 1, 8, 5, 2, 6, 3, 5]
# [3, 8, 6, 2, 5, 1, 6, 2]
# [8, 6, 3, 1, 2, 5, 8, 4]
# [5, 7, 4, 1, 3, 8, 6, 1]
# [8, 3, 4, 6, 2, 5, 2, 1]
# [5, 3, 1, 7, 8, 2, 6, 2]
# [8, 5, 1, 4, 6, 3, 2, 5]
# [7, 8, 6, 2, 3, 5, 6, 4]
# [3, 5, 7, 2, 4, 8, 1, 3]
# [8, 6, 2, 4, 5, 3, 7, 1]
# [8, 7, 5, 3, 6, 4, 1, 6]
# [5, 2, 8, 3, 7, 6, 1, 3]
# [1, 6, 8, 2, 4, 7, 6, 3]
# [4, 8, 7, 5, 2, 6, 1, 3]
# [4, 1, 8, 6, 2, 7, 5, 3]
# [1, 6, 8, 7, 2, 4, 1, 3]
# [8, 5, 3, 1, 6, 4, 1, 7]
# [3, 8, 2, 4, 1, 7, 8, 6]
# [8, 4, 7, 5, 2, 6, 1, 3]
# [8, 2, 6, 3, 1, 7, 5, 2]
# [8, 2, 6, 1, 1, 8, 4, 7]
# [3, 5, 7, 1, 8, 2, 6, 8]
# [8, 2, 4, 1, 3, 7, 5, 6]
# [8, 5, 3, 1, 4, 7, 3, 6]
# [8, 2, 7, 4, 5, 1, 6, 3]
# [8, 2, 4, 1, 3, 2, 1, 4]
# [8, 5, 1, 4, 6, 7, 3, 5]
# [2, 4, 7, 8, 3, 2, 1, 4]
# [3, 5, 8, 1, 4, 2, 7, 5]
# [8, 4, 1, 1, 6, 2, 4, 6]
# [8, 5, 3, 1, 3, 4, 2, 7]
# [8, 3, 2, 7, 5, 7, 1, 4]
# [4, 8, 7, 3, 6, 8, 2, 5]
# [8, 2, 8, 1, 7, 4, 6, 3]
# [3, 8, 4, 8, 5, 2, 7, 1]
# [8, 3, 6, 2, 7, 1, 2, 4]
# [8, 1, 5, 2, 6, 6, 1, 4]
# [2, 4, 8, 3, 5, 1, 6, 4]
# [3, 6, 8, 8, 4, 1, 7, 2]
# [4, 8, 1, 5, 6, 3, 3, 7]
# [2, 5, 8, 5, 1, 3, 1, 6]
# [3, 1, 8, 7, 2, 4, 3, 6]
# [4, 1, 5, 2, 8, 6, 1, 5]
# [6, 3, 7, 2, 8, 5, 4, 1]
# [8, 5, 1, 4, 3, 7, 4, 2]
# [8, 6, 3, 1, 4, 5, 2, 7]
# [7, 4, 1, 8, 1, 5, 2, 8]
# [8, 3, 7, 2, 2, 1, 4, 5]
# [8, 6, 4, 2, 5, 6, 7, 1]
# [5, 8, 6, 3, 7, 1, 4, 2]
# [3, 6, 8, 1, 5, 4, 2, 7]
# [8, 1, 5, 2, 6, 3, 7, 4]
# [8, 2, 4, 7, 3, 1, 6, 2]
# [8, 1, 5, 2, 8, 7, 3, 6]
# [4, 8, 5, 4, 1, 7, 2, 6]
# [8, 3, 5, 7, 1, 4, 6, 6]
# [8, 4, 6, 1, 5, 2, 5, 3]
# [8, 3, 5, 7, 4, 1, 8, 4]
# [7, 8, 4, 6, 1, 3, 5, 6]
# [3, 8, 1, 2, 6, 8, 5, 7]
# [2, 6, 8, 1, 7, 5, 3, 5]
# [4, 8, 2, 6, 1, 3, 7, 5]
# [2, 8, 1, 4, 7, 6, 3, 5]
# [8, 7, 2, 6, 3, 1, 8, 5]
# [6, 1, 8, 3, 7, 7, 4, 2]
# [8, 6, 2, 3, 7, 6, 4, 8]
# [5, 2, 4, 7, 8, 7, 3, 1]
# [2, 6, 1, 8, 7, 3, 3, 6]
# [1, 3, 7, 8, 2, 5, 6, 4]
# [3, 6, 8, 2, 4, 1, 7, 4]
# [5, 7, 8, 6, 2, 8, 1, 3]
# [3, 7, 4, 1, 8, 8, 5, 2]
# [6, 8, 1, 4, 1, 2, 7, 3]
# [2, 8, 6, 3, 7, 4, 1, 8]
# [7, 1, 8, 6, 2, 4, 7, 3]
# [8, 6, 3, 7, 2, 4, 3, 1]
# [8, 7, 4, 7, 2, 5, 1, 3]
# [8, 3, 6, 4, 5, 2, 5, 1]
# [5, 8, 2, 7, 3, 4, 1, 8]
# [8, 6, 3, 5, 2, 1, 3, 4]
# [8, 5, 2, 4, 1, 3, 7, 3]
# [5, 8, 4, 8, 3, 2, 7, 1]
# [8, 7, 3, 4, 2, 5, 1, 6]
# [3, 5, 8, 3, 4, 2, 7, 1]
# [8, 5, 7, 2, 6, 3, 1, 5]
# [3, 7, 4, 1, 8, 2, 5, 7]
# [3, 5, 2, 8, 1, 4, 3, 8]
# [3, 8, 7, 1, 2, 4, 8, 3]
# [8, 5, 1, 7, 5, 2, 4, 3]
# [8, 4, 2, 4, 3, 1, 7, 5]
# [3, 8, 2, 5, 1, 4, 7, 6]
# [8, 6, 7, 2, 6, 1, 3, 5]
# [7, 4, 8, 1, 6, 3, 5, 2]
# [6, 8, 1, 7, 5, 2, 1, 1]
# [8, 5, 1, 5, 7, 2, 8, 6]
# [8, 6, 1, 5, 8, 2, 3, 7]
# [8, 2, 4, 6, 5, 3, 1, 6]
# [8, 2, 3, 8, 4, 5, 1, 6]
# [8, 6, 2, 7, 5, 3, 6, 5]
# [3, 1, 4, 8, 5, 2, 7, 1]
# [8, 4, 7, 3, 6, 2, 6, 5]
# [4, 6, 1, 8, 7, 5, 2, 1]
# [7, 5, 2, 8, 6, 3, 4, 1]
# [2, 7, 8, 3, 1, 4, 5, 2]
# [3, 5, 7, 8, 1, 6, 2, 4]
# [8, 3, 1, 2, 7, 8, 6, 5]
# [7, 1, 8, 5, 2, 4, 8, 3]
# [7, 1, 6, 2, 5, 8, 4, 8]
# [3, 1, 8, 2, 5, 7, 3, 2]
# [8, 6, 2, 3, 1, 4, 7, 6]
# [8, 3, 5, 2, 3, 1, 7, 4]
# [2, 8, 3, 6, 4, 1, 2, 7]
# [8, 5, 7, 2, 4, 6, 1, 3]
# [3, 8, 2, 4, 5, 7, 8, 1]
# [8, 5, 1, 6, 2, 7, 4, 6]
# [8, 2, 5, 7, 4, 1, 5, 2]
# [6, 8, 2, 5, 1, 4, 6, 5]
# [3, 8, 2, 7, 4, 2, 1, 8]
# [1, 8, 4, 7, 3, 5, 2, 1]
# [3, 7, 2, 8, 5, 1, 7, 6]
# [8, 3, 7, 5, 2, 1, 1, 4]
# [6, 8, 5, 2, 4, 7, 3, 1]
# [3, 8, 2, 1, 6, 4, 5, 7]
# [4, 1, 5, 2, 6, 3, 8, 6]
# [8, 6, 2, 2, 5, 3, 7, 4]
# [1, 4, 8, 5, 6, 2, 3, 4]
# [5, 8, 2, 7, 4, 6, 3, 7]
# [4, 8, 3, 6, 2, 1, 5, 1]
# [8, 2, 6, 3, 1, 7, 4, 3]
# [2, 5, 8, 4, 7, 4, 3, 6]
# [4, 7, 8, 1, 5, 1, 6, 2]
# [8, 3, 6, 7, 5, 2, 8, 1]
# [1, 5, 8, 2, 3, 7, 4, 7]
# [8, 3, 7, 2, 4, 1, 5, 8]
# [6, 3, 1, 4, 7, 5, 8, 2]
# [3, 8, 7, 2, 6, 1, 4, 1]
# [8, 8, 4, 7, 1, 3, 6, 2]
# [8, 3, 7, 4, 1, 5, 2, 6]
# [8, 5, 2, 4, 2, 7, 3, 1]
# [6, 3, 7, 2, 8, 5, 1, 3]
# [1, 8, 6, 3, 7, 2, 7, 5]
# [8, 3, 6, 7, 1, 4, 7, 3]
# [7, 2, 8, 5, 4, 1, 3, 6]
# [8, 3, 1, 2, 5, 7, 6, 8]
# [8, 3, 2, 4, 2, 1, 6, 8]
# [5, 3, 1, 7, 8, 5, 6, 2]
# [8, 5, 1, 4, 7, 3, 2, 6]
# [8, 5, 7, 2, 3, 4, 6, 1]
# [6, 4, 2, 8, 6, 3, 1, 2]
# [7, 1, 6, 8, 2, 4, 1, 3]
# [8, 5, 4, 1, 3, 6, 2, 7]
# [1, 3, 5, 8, 6, 4, 2, 8]
# [3, 6, 8, 1, 2, 4, 6, 2]
# [8, 3, 1, 7, 2, 6, 6, 4]
# [4, 7, 3, 8, 2, 5, 1, 6]
# [7, 2, 8, 3, 5, 4, 3, 1]
# [5, 3, 1, 7, 8, 7, 2, 5]
# [8, 3, 4, 2, 7, 5, 1, 7]
# [8, 5, 5, 3, 1, 6, 4, 2]
# [2, 8, 7, 6, 2, 3, 1, 4]
# [8, 1, 5, 6, 2, 7, 1, 4]
# [3, 8, 6, 1, 5, 7, 2, 8]
# [5, 2, 8, 5, 4, 7, 1, 6]
# [1, 3, 8, 6, 8, 2, 5, 7]
# [2, 7, 5, 8, 7, 1, 3, 6]
# [6, 4, 8, 7, 3, 2, 5, 1]
# [6, 1, 3, 5, 8, 6, 4, 2]
# [8, 5, 2, 4, 1, 3, 2, 6]
# [8, 3, 7, 4, 2, 5, 2, 1]
# [3, 7, 4, 2, 8, 5, 1, 2]
# [8, 6, 4, 1, 4, 7, 2, 3]
# [3, 8, 4, 1, 7, 2, 6, 7]
# [5, 7, 8, 1, 6, 3, 1, 4]
# [4, 8, 5, 6, 2, 1, 3, 7]
# [2, 5, 8, 1, 6, 4, 7, 7]
# [7, 8, 3, 5, 6, 1, 4, 2]
# [8, 5, 1, 8, 4, 2, 6, 3]
# [3, 8, 2, 5, 1, 4, 6, 8]
# [2, 8, 5, 3, 1, 4, 7, 6]
# [8, 1, 1, 6, 2, 7, 1, 4]
# [4, 7, 5, 2, 8, 1, 6, 1]
# [2, 4, 1, 3, 8, 6, 7, 5]
# [8, 7, 3, 5, 2, 4, 1, 8]
# [6, 8, 1, 4, 6, 8, 3, 1]
# [5, 3, 1, 4, 8, 4, 2, 7]
# [3, 8, 4, 1, 4, 2, 5, 4]
# [5, 8, 2, 4, 7, 1, 3, 6]
# [8, 5, 7, 2, 4, 6, 1, 3]
# [2, 5, 8, 2, 4, 3, 1, 3]
# [8, 7, 2, 6, 3, 1, 4, 5]
# [4, 8, 2, 3, 5, 8, 1, 4]
# [8, 6, 2, 7, 5, 1, 8, 4]
# [8, 5, 1, 6, 3, 1, 4, 2]
# [4, 8, 2, 5, 1, 3, 6, 8]
# [5, 8, 6, 3, 7, 2, 4, 1]
# [8, 6, 2, 8, 1, 7, 4, 5]
# [8, 2, 4, 1, 7, 5, 4, 3]
# [8, 3, 6, 7, 1, 4, 5, 7]
# [8, 3, 7, 1, 4, 3, 8, 6]
# [8, 6, 2, 5, 1, 3, 4, 3]
# [4, 2, 8, 3, 4, 7, 1, 6]
# [3, 8, 6, 2, 5, 1, 4, 7]
# [8, 1, 5, 7, 2, 4, 3, 8]
# [4, 6, 8, 4, 1, 3, 7, 2]
# [8, 2, 5, 3, 1, 7, 4, 6]
# [6, 8, 7, 2, 6, 3, 1, 4]
# [8, 6, 1, 3, 5, 7, 2, 4]
# [8, 7, 2, 5, 1, 4, 3, 5]
# [6, 8, 2, 4, 1, 7, 3, 4]
# [8, 4, 5, 3, 1, 7, 6, 5]
# [6, 2, 7, 8, 1, 5, 3, 1]
# [4, 2, 7, 3, 8, 6, 4, 1]
# [1, 3, 6, 8, 2, 6, 5, 7]
# [3, 5, 7, 1, 6, 8, 2, 7]
# [8, 5, 1, 4, 2, 7, 3, 4]
# [4, 7, 1, 8, 5, 2, 7, 3]
# [7, 3, 8, 2, 5, 6, 4, 1]
# [8, 3, 1, 7, 4, 2, 1, 5]
# [6, 8, 1, 4, 7, 6, 2, 5]
# [3, 6, 2, 7, 8, 4, 5, 1]
# [1, 6, 4, 8, 1, 3, 5, 2]
# [2, 8, 5, 8, 1, 6, 3, 1]
# [8, 3, 4, 6, 2, 1, 5, 4]
# [4, 7, 8, 3, 6, 1, 5, 2]
# [4, 7, 8, 3, 5, 8, 5, 6]
# [8, 6, 2, 5, 5, 1, 7, 4]
# [8, 3, 5, 7, 4, 1, 6, 7]
# [8, 5, 2, 2, 1, 3, 5, 4]
# [8, 6, 1, 3, 2, 5, 7, 4]
# [8, 2, 5, 3, 1, 7, 4, 6]
# [8, 1, 5, 7, 2, 4, 3, 4]
# [8, 3, 6, 4, 2, 4, 5, 7]
# [5, 8, 1, 7, 6, 2, 2, 4]
# [2, 8, 5, 6, 3, 1, 4, 7]
# [8, 4, 6, 3, 4, 1, 7, 5]
# [8, 2, 7, 3, 1, 1, 4, 5]
# [2, 4, 7, 8, 3, 6, 5, 1]
# [4, 8, 5, 1, 6, 6, 7, 2]
# [8, 7, 2, 6, 3, 1, 4, 2]
# [2, 4, 8, 1, 2, 6, 3, 7]
# [8, 5, 2, 4, 1, 7, 2, 6]
# [8, 4, 1, 7, 5, 2, 6, 3]
# [5, 8, 5, 3, 7, 2, 4, 1]
# [8, 3, 1, 6, 2, 5, 7, 4]
# [5, 8, 1, 5, 6, 7, 3, 1]
# [8, 6, 4, 4, 1, 5, 7, 8]
# [8, 2, 5, 3, 1, 4, 6, 5]
# [8, 6, 2, 5, 3, 1, 4, 3]
# [2, 8, 6, 3, 1, 4, 5, 5]
# [8, 6, 3, 1, 7, 4, 2, 3]
# [7, 8, 6, 2, 4, 7, 3, 5]
# [3, 8, 2, 8, 1, 4, 7, 6]
# [6, 1, 8, 2, 7, 3, 4, 6]
# [8, 4, 2, 3, 5, 7, 1, 6]
# [8, 5, 2, 1, 7, 4, 5, 3]
# [8, 4, 6, 3, 5, 7, 1, 1]
# [6, 2, 5, 1, 4, 7, 8, 3]
# [5, 8, 5, 3, 7, 2, 4, 6]
# [7, 8, 6, 3, 1, 4, 5, 8]
# [3, 5, 8, 4, 1, 7, 2, 8]
# [8, 1, 3, 7, 6, 4, 2, 5]
# [8, 2, 4, 6, 1, 3, 5, 7]
# [8, 5, 1, 7, 5, 2, 6, 3]
# [8, 7, 4, 5, 3, 6, 1, 5]
# [7, 8, 5, 3, 1, 4, 2, 6]
# [8, 4, 7, 5, 2, 1, 6, 2]
# [8, 6, 1, 3, 5, 7, 2, 4]
# [8, 4, 1, 5, 2, 6, 3, 7]
# [8, 6, 1, 7, 5, 3, 8, 2]
# [8, 5, 2, 3, 6, 3, 1, 8]
# [2, 5, 7, 1, 8, 3, 6, 3]
# [7, 8, 3, 6, 5, 4, 2, 8]
# [6, 3, 8, 7, 1, 5, 2, 3]
# [8, 7, 4, 2, 1, 3, 6, 5]
# [5, 2, 8, 7, 6, 1, 3, 8]
# [8, 1, 4, 2, 7, 6, 5, 3]
# [8, 4, 2, 6, 7, 1, 4, 5]
# [6, 3, 1, 8, 7, 2, 4, 8]
# [8, 1, 4, 2, 7, 5, 3, 1]
# [6, 8, 2, 7, 1, 3, 5, 7]
# [6, 1, 7, 2, 8, 4, 8, 3]
# [6, 8, 2, 7, 3, 1, 4, 6]
# [3, 8, 3, 7, 2, 6, 1, 8]
# [8, 1, 6, 2, 5, 7, 5, 3]
# [5, 8, 1, 3, 6, 8, 2, 4]
# [5, 8, 1, 7, 2, 6, 8, 3]
# [3, 8, 8, 4, 1, 5, 2, 6]
# [2, 8, 6, 5, 1, 4, 1, 2]
# [5, 1, 8, 4, 3, 7, 4, 2]
# [8, 2, 6, 1, 3, 5, 8, 4]
# [8, 3, 2, 4, 7, 1, 6, 5]
# [4, 8, 3, 5, 2, 1, 2, 6]
# [8, 6, 5, 2, 4, 1, 7, 3]
# [5, 2, 8, 8, 7, 1, 3, 1]
# [2, 4, 8, 7, 5, 1, 6, 1]
# [7, 1, 4, 8, 5, 2, 4, 6]
# [3, 1, 6, 4, 8, 7, 5, 2]
# [8, 4, 2, 7, 5, 6, 3, 8]
# [8, 5, 7, 1, 4, 6, 2, 3]
# [8, 8, 1, 4, 6, 1, 3, 5]
# [6, 3, 7, 4, 8, 1, 2, 4]
# [8, 1, 5, 8, 6, 3, 7, 2]
# [8, 1, 4, 7, 8, 2, 5, 3]
# [4, 7, 8, 2, 6, 1, 3, 5]
# [4, 8, 3, 2, 5, 6, 6, 7]
# [8, 3, 1, 8, 2, 5, 7, 2]
# [4, 8, 5, 3, 1, 6, 4, 7]
# [8, 2, 5, 8, 1, 2, 4, 6]
# [4, 7, 8, 3, 6, 7, 5, 5]
# [3, 6, 8, 1, 3, 7, 5, 8]
# [8, 1, 5, 3, 6, 4, 2, 1]
# [7, 5, 2, 6, 1, 8, 5, 3]
# [4, 1, 3, 8, 2, 2, 7, 6]
# [8, 1, 6, 2, 3, 7, 7, 5]
# [2, 5, 7, 4, 1, 3, 8, 6]
# [4, 7, 8, 3, 6, 1, 5, 2]
# [8, 6, 4, 1, 5, 4, 2, 7]
# [2, 4, 8, 7, 3, 1, 6, 8]
# [5, 8, 6, 4, 7, 3, 4, 2]
# [8, 1, 6, 4, 2, 7, 5, 1]
# [3, 6, 2, 5, 1, 8, 4, 3]
# [8, 5, 4, 6, 1, 7, 5, 3]
# [2, 8, 1, 6, 4, 8, 1, 5]
# [8, 6, 8, 2, 4, 1, 7, 5]
# [2, 8, 8, 4, 1, 8, 5, 1]
# [8, 2, 4, 7, 5, 1, 2, 4]
# [4, 8, 1, 5, 2, 2, 6, 3]
# [8, 7, 4, 2, 5, 7, 1, 3]
# [2, 5, 8, 6, 3, 3, 7, 1]
# [8, 2, 4, 7, 3, 2, 6, 1]
# [6, 4, 2, 8, 3, 7, 1, 2]
# [8, 2, 6, 1, 7, 6, 4, 3]
# [6, 3, 8, 7, 4, 2, 5, 3]
# [4, 8, 4, 3, 1, 7, 2, 6]
# [8, 2, 4, 1, 7, 5, 3, 6]
# [5, 3, 8, 4, 2, 1, 6, 5]
# [8, 6, 1, 3, 5, 1, 7, 2]
# [4, 8, 5, 2, 3, 1, 6, 3]
# [8, 6, 1, 5, 2, 6, 3, 7]
# [4, 1, 8, 5, 3, 1, 7, 2]
# [8, 5, 7, 2, 3, 5, 8, 1]
# [8, 6, 3, 5, 8, 1, 5, 7]
# [1, 8, 5, 8, 2, 7, 3, 4]
# [1, 8, 6, 3, 7, 2, 8, 5]
# [8, 7, 4, 2, 7, 5, 6, 1]
# [8, 7, 2, 5, 6, 4, 1, 3]
# [3, 6, 2, 8, 1, 4, 7, 5]
# [7, 8, 2, 3, 1, 5, 6, 8]
# [1, 6, 8, 5, 2, 7, 8, 4]
# [5, 8, 6, 3, 7, 4, 1, 5]
# [4, 8, 1, 5, 2, 3, 6, 7]
# [7, 3, 8, 3, 5, 2, 4, 6]
# [6, 8, 3, 1, 7, 4, 6, 5]
# [8, 2, 6, 1, 8, 4, 5, 7]
# [6, 8, 3, 7, 1, 4, 6, 5]
# [8, 7, 2, 3, 5, 7, 4, 2]
# [8, 3, 1, 7, 5, 6, 3, 4]
# [3, 8, 7, 2, 4, 1, 5, 1]
# [5, 8, 1, 1, 7, 2, 1, 7]
# [3, 6, 8, 7, 2, 4, 6, 1]
# [8, 3, 5, 7, 4, 1, 3, 2]
# [1, 8, 6, 1, 3, 7, 4, 2]
# [7, 4, 1, 5, 2, 8, 3, 7]
# [6, 8, 1, 7, 4, 2, 7, 5]
# [8, 1, 4, 1, 2, 7, 3, 6]
# [4, 8, 2, 2, 4, 7, 1, 5]
# [8, 3, 6, 5, 1, 4, 2, 7]
# [5, 8, 4, 1, 3, 8, 2, 1]
# [8, 2, 1, 4, 1, 5, 3, 6]
# [8, 5, 7, 1, 3, 8, 2, 4]
# [8, 1, 4, 2, 7, 3, 5, 8]
# [6, 8, 5, 1, 5, 7, 4, 2]
# [8, 5, 1, 6, 4, 7, 7, 2]
# [7, 2, 6, 8, 1, 4, 7, 3]
# [2, 8, 1, 7, 5, 3, 6, 4]
# [2, 8, 3, 4, 6, 1, 3, 5]
# [6, 3, 8, 7, 1, 4, 2, 6]
# [8, 1, 6, 3, 1, 7, 4, 2]
# [2, 4, 8, 1, 2, 5, 3, 4]
# [3, 8, 7, 2, 6, 5, 4, 4]
# [8, 4, 1, 3, 6, 4, 7, 2]
# [2, 5, 1, 8, 7, 3, 6, 2]
# [1, 7, 8, 1, 3, 7, 4, 2]
# [8, 2, 3, 1, 7, 4, 6, 8]
# [4, 7, 1, 8, 6, 4, 3, 2]
# [8, 7, 1, 2, 5, 3, 6, 2]
# [8, 6, 4, 1, 6, 3, 5, 1]
# [8, 6, 2, 5, 1, 4, 7, 3]
# [7, 8, 4, 6, 1, 5, 2, 7]
# [8, 3, 4, 2, 7, 1, 2, 5]
# [7, 8, 2, 5, 1, 6, 4, 5]
# [2, 8, 3, 4, 1, 5, 6, 1]
# [8, 5, 2, 4, 7, 8, 4, 1]
# [8, 3, 1, 4, 2, 5, 7, 6]
# [8, 5, 4, 2, 7, 8, 6, 1]
# [1, 3, 8, 6, 4, 2, 6, 5]
# [8, 2, 7, 8, 3, 1, 6, 4]
# [8, 6, 1, 3, 2, 3, 6, 4]
# [8, 6, 3, 2, 5, 1, 4, 2]
# [5, 1, 4, 7, 3, 6, 8, 2]
# [3, 5, 8, 4, 5, 2, 1, 6]
# [2, 8, 6, 7, 3, 1, 4, 5]
# [5, 3, 1, 4, 8, 8, 6, 2]
# [8, 7, 2, 6, 3, 1, 4, 5]
# [4, 1, 8, 3, 6, 1, 5, 2]
# [8, 4, 7, 1, 3, 6, 8, 1]
# [6, 8, 5, 1, 3, 2, 7, 3]
# [8, 2, 7, 3, 5, 6, 1, 5]
# [2, 8, 5, 1, 7, 4, 8, 4]
# [8, 7, 6, 4, 3, 1, 2, 5]
# [8, 1, 4, 7, 2, 6, 3, 8]
# [7, 1, 4, 8, 5, 6, 2, 3]
# [1, 8, 6, 2, 4, 8, 3, 5]
# [1, 8, 7, 3, 6, 8, 5, 4]
# [4, 7, 8, 3, 5, 1, 8, 6]
# [2, 6, 8, 1, 4, 3, 7, 2]
# [8, 4, 6, 8, 2, 5, 1, 7]
# [4, 7, 8, 3, 6, 4, 5, 2]
# [1, 4, 7, 5, 8, 2, 6, 3]
# [2, 8, 5, 4, 7, 1, 6, 1]
# [6, 4, 1, 2, 8, 7, 4, 5]
# [2, 4, 8, 1, 5, 7, 6, 8]
# [8, 6, 1, 5, 6, 8, 4, 7]
# [8, 7, 1, 5, 3, 6, 4, 5]
# [7, 8, 3, 6, 2, 7, 5, 1]
# [2, 4, 8, 8, 3, 1, 6, 5]
# [3, 5, 8, 1, 6, 4, 2, 5]
# [1, 3, 8, 6, 4, 2, 8, 5]
# [8, 6, 1, 3, 6, 4, 6, 2]
# [8, 6, 1, 3, 5, 3, 7, 2]
# [7, 2, 8, 4, 6, 1, 3, 5]
# [8, 7, 3, 6, 2, 5, 1, 6]
# [4, 7, 8, 6, 2, 2, 5, 3]
# [6, 8, 7, 1, 6, 5, 2, 4]
# [3, 7, 4, 1, 8, 5, 4, 2]
# [3, 6, 8, 2, 8, 1, 4, 8]
# [4, 7, 5, 8, 1, 1, 6, 2]
# [8, 1, 4, 2, 7, 3, 6, 6]
# [8, 7, 5, 2, 6, 1, 7, 4]
# [4, 8, 7, 3, 6, 2, 5, 6]
# [2, 8, 6, 8, 1, 4, 8, 7]
# [3, 5, 8, 7, 1, 8, 2, 6]
# [8, 4, 3, 1, 5, 2, 6, 4]
# [1, 3, 8, 7, 4, 2, 5, 2]
# [1, 4, 7, 3, 8, 5, 2, 6]
# [8, 7, 2, 4, 6, 1, 3, 5]
# [8, 5, 1, 6, 8, 7, 4, 2]
# [3, 8, 3, 5, 1, 2, 6, 3]
# [8, 5, 3, 7, 2, 4, 6, 1]
# [8, 3, 2, 6, 7, 6, 1, 4]
# [8, 6, 4, 1, 7, 5, 1, 2]
# [7, 8, 4, 6, 1, 5, 2, 5]
# [5, 8, 2, 7, 3, 1, 6, 2]
# [4, 8, 3, 6, 1, 3, 5, 2]
# [8, 5, 2, 6, 3, 7, 4, 1]
# [1, 8, 6, 2, 4, 7, 3, 5]
# [1, 7, 8, 4, 2, 5, 3, 6]
# [8, 6, 2, 3, 1, 4, 7, 5]
# [8, 3, 5, 2, 7, 1, 6, 1]
# [7, 5, 8, 2, 6, 1, 3, 4]
# [7, 4, 1, 3, 6, 8, 2, 3]
# [2, 8, 5, 7, 1, 3, 6, 7]
# [8, 4, 7, 1, 3, 5, 2, 8]
# [8, 6, 1, 3, 4, 2, 1, 4]
# [6, 3, 7, 4, 8, 5, 7, 1]
# [1, 8, 6, 2, 3, 8, 4, 7]
# [6, 8, 5, 2, 6, 3, 6, 1]
# [4, 8, 1, 5, 2, 7, 6, 4]
# [7, 4, 2, 5, 8, 6, 4, 3]
# [8, 6, 4, 2, 7, 5, 3, 1]
# [5, 8, 1, 7, 8, 3, 6, 4]
# [8, 7, 4, 1, 2, 3, 5, 2]
# [8, 1, 4, 3, 3, 5, 7, 4]
# [8, 4, 2, 5, 3, 1, 8, 7]
# [8, 4, 7, 1, 6, 2, 3, 4]
# [6, 8, 1, 4, 5, 7, 2, 6]
# [8, 7, 4, 2, 5, 3, 1, 4]
# [8, 1, 6, 2, 7, 5, 4, 7]
# [8, 7, 3, 1, 7, 2, 5, 3]
# [1, 5, 7, 8, 4, 2, 8, 3]
# [6, 3, 7, 2, 8, 2, 4, 1]
# [3, 5, 8, 1, 6, 4, 2, 1]
# [8, 6, 1, 5, 2, 6, 3, 7]
# [8, 5, 1, 4, 3, 6, 3, 2]
# [8, 5, 7, 1, 6, 2, 5, 4]
# [3, 8, 6, 2, 5, 1, 6, 4]
# [8, 5, 1, 4, 7, 1, 3, 5]
# [3, 8, 6, 2, 5, 7, 1, 4]
# [8, 4, 6, 3, 2, 7, 1, 6]
# [6, 4, 1, 5, 8, 5, 3, 7]
# [8, 5, 3, 2, 7, 4, 6, 8]
# [7, 4, 1, 3, 8, 6, 8, 2]
# [3, 8, 2, 4, 5, 1, 3, 6]
# [7, 8, 1, 6, 2, 3, 5, 8]
# [6, 1, 3, 5, 8, 2, 4, 1]
# [8, 2, 4, 7, 1, 5, 6, 1]
# [1, 8, 4, 2, 7, 6, 6, 3]
# [8, 1, 5, 7, 3, 6, 4, 2]
# [4, 7, 5, 2, 8, 1, 6, 7]
# [8, 7, 6, 3, 1, 2, 4, 5]
# [8, 3, 6, 3, 1, 7, 4, 6]
# [7, 8, 4, 1, 8, 6, 3, 1]
# [6, 8, 2, 2, 1, 4, 5, 3]
# [6, 3, 8, 8, 1, 5, 2, 8]
# [6, 1, 8, 2, 7, 3, 5, 6]
# [8, 4, 1, 3, 6, 2, 7, 5]
# [3, 6, 8, 2, 1, 7, 4, 1]
# [2, 8, 6, 4, 1, 3, 5, 8]
# [1, 4, 8, 1, 2, 4, 5, 7]
# [6, 3, 7, 2, 8, 1, 4, 7]
# [2, 7, 8, 1, 5, 8, 6, 4]
# [7, 3, 8, 2, 5, 6, 4, 1]
# [8, 6, 1, 3, 6, 5, 4, 2]
# [5, 8, 4, 7, 3, 1, 6, 8]
# [3, 8, 4, 2, 2, 1, 7, 5]
# [3, 6, 8, 7, 1, 4, 2, 5]
# [1, 6, 8, 2, 4, 1, 5, 3]
# [1, 8, 2, 7, 6, 3, 5, 3]
# [8, 5, 3, 6, 2, 4, 7, 1]
# [8, 6, 5, 3, 1, 7, 2, 1]
# [2, 5, 8, 6, 4, 3, 7, 5]
# [4, 1, 7, 8, 2, 5, 6, 3]
# [8, 1, 5, 2, 3, 7, 4, 6]
# [8, 4, 3, 1, 6, 2, 7, 3]
# [3, 6, 2, 5, 1, 8, 4, 6]
# [4, 2, 7, 8, 6, 3, 1, 8]
# [3, 8, 7, 5, 2, 4, 6, 8]
# [1, 8, 7, 2, 4, 3, 6, 1]
# [3, 5, 2, 8, 1, 4, 2, 7]
# [5, 8, 6, 4, 2, 4, 1, 3]
# [8, 7, 4, 2, 1, 5, 6, 4]
# [7, 8, 8, 5, 2, 6, 6, 4]
# [8, 1, 5, 2, 4, 3, 6, 4]
# [8, 2, 7, 3, 6, 2, 1, 4]
# [5, 3, 1, 8, 8, 6, 2, 7]
# [4, 7, 1, 8, 5, 2, 7, 3]
# [7, 4, 8, 1, 2, 6, 3, 7]
# [3, 6, 8, 2, 5, 7, 4, 1]
# [1, 8, 6, 1, 2, 7, 5, 4]
# [4, 7, 3, 8, 6, 5, 1, 2]
# [2, 4, 8, 4, 5, 3, 1, 7]
# [2, 4, 6, 1, 3, 5, 8, 1]
# [3, 7, 2, 8, 6, 1, 5, 8]
# [5, 8, 1, 4, 3, 8, 7, 2]
# [8, 6, 1, 3, 5, 7, 2, 4]
# [8, 6, 3, 2, 7, 2, 1, 3]
# [4, 8, 6, 3, 7, 2, 5, 1]
# [3, 8, 4, 2, 5, 6, 1, 7]
# [8, 2, 2, 7, 1, 3, 4, 6]
# [4, 8, 1, 5, 2, 6, 7, 3]
# [3, 8, 7, 4, 1, 5, 6, 7]
# [8, 6, 5, 3, 1, 8, 7, 2]
# [8, 4, 2, 5, 3, 1, 8, 4]
# [5, 3, 8, 4, 7, 5, 2, 1]
# [3, 8, 7, 2, 6, 1, 3, 8]
# [8, 1, 5, 1, 6, 5, 3, 2]
# [3, 8, 6, 1, 5, 4, 3, 7]
# [7, 3, 8, 5, 1, 3, 4, 6]
# [8, 1, 4, 7, 5, 2, 8, 6]
# [8, 3, 7, 2, 1, 5, 4, 3]
# [5, 2, 8, 3, 6, 1, 5, 4]
# [2, 8, 6, 3, 1, 4, 5, 8]
# [5, 2, 6, 1, 3, 8, 6, 4]
# [6, 4, 2, 8, 5, 7, 3, 1]
# [8, 7, 2, 4, 1, 5, 3, 1]
# [5, 1, 6, 4, 2, 8, 4, 3]
# [7, 8, 1, 5, 2, 6, 4, 8]
# [4, 2, 8, 5, 1, 4, 1, 7]
# [3, 6, 2, 5, 8, 1, 4, 5]
# [7, 8, 3, 8, 4, 1, 2, 6]
# [2, 6, 3, 8, 4, 1, 5, 6]
# [8, 3, 7, 4, 1, 6, 2, 5]
# [8, 2, 5, 3, 1, 4, 6, 5]
# [8, 8, 3, 6, 2, 1, 4, 5]
# [8, 3, 4, 2, 7, 6, 1, 8]
# [8, 6, 4, 1, 1, 3, 7, 4]
# [6, 4, 8, 7, 3, 5, 2, 8]
# [6, 8, 3, 5, 1, 2, 4, 7]
# [8, 7, 2, 6, 3, 1, 4, 7]
# [8, 5, 3, 7, 5, 1, 6, 2]
# [8, 6, 1, 2, 7, 4, 2, 3]
# [8, 7, 1, 3, 8, 6, 4, 2]
# [5, 8, 2, 3, 6, 7, 1, 4]
# [8, 3, 2, 4, 1, 8, 5, 1]
# [6, 8, 3, 1, 7, 2, 5, 6]
# [1, 5, 2, 8, 8, 3, 6, 6]
# [8, 5, 7, 6, 3, 1, 7, 6]
# [1, 8, 6, 2, 7, 1, 3, 5]
# [5, 1, 4, 7, 3, 8, 2, 4]
# [8, 2, 7, 3, 1, 8, 4, 2]
# [8, 4, 7, 5, 2, 6, 1, 8]
# [8, 2, 5, 3, 1, 4, 2, 7]
# [3, 6, 8, 1, 4, 1, 7, 2]
# [3, 5, 8, 4, 1, 7, 4, 6]
# [6, 8, 3, 1, 8, 2, 7, 5]
# [4, 8, 1, 7, 5, 2, 1, 3]
# [6, 2, 5, 8, 1, 3, 4, 7]
# [6, 4, 8, 1, 5, 2, 1, 6]
# [8, 2, 5, 1, 4, 5, 3, 6]
# [8, 2, 4, 7, 3, 7, 6, 1]
# [8, 3, 6, 5, 4, 2, 1, 8]
# [8, 3, 5, 7, 1, 4, 2, 7]
# [8, 5, 1, 6, 4, 7, 3, 8]
# [8, 4, 1, 2, 5, 3, 6, 5]
# [6, 8, 1, 5, 7, 2, 3, 4]
# [1, 5, 8, 6, 4, 7, 3, 7]
# [1, 3, 7, 8, 6, 5, 2, 4]
# [8, 1, 6, 4, 3, 7, 5, 2]
# [8, 1, 4, 3, 7, 5, 2, 6]
# [3, 7, 2, 8, 1, 4, 7, 5]
# [8, 6, 6, 3, 1, 4, 7, 5]
# [3, 8, 1, 4, 2, 7, 6, 8]
# [3, 6, 4, 8, 1, 5, 2, 8]
# [1, 8, 8, 7, 4, 2, 3, 5]
# [2, 8, 6, 3, 1, 4, 7, 2]
# [7, 4, 2, 8, 6, 1, 3, 7]
# [7, 1, 4, 8, 4, 3, 5, 2]
# [1, 3, 6, 8, 7, 5, 4, 2]
# [5, 2, 8, 1, 3, 7, 6, 4]
# [3, 7, 4, 8, 4, 5, 1, 6]
# [7, 3, 8, 3, 5, 1, 2, 4]
# [4, 1, 7, 8, 3, 8, 2, 5]
# [4, 8, 5, 3, 6, 7, 2, 1]
# [8, 3, 6, 2, 7, 1, 2, 5]
# [8, 3, 5, 2, 4, 1, 5, 8]
# [8, 7, 2, 5, 4, 3, 1, 4]
# [3, 7, 4, 1, 8, 2, 5, 6]
# [8, 7, 5, 3, 1, 4, 2, 6]
# [7, 1, 6, 2, 8, 4, 3, 5]
# [7, 3, 6, 2, 5, 1, 8, 4]
# [8, 1, 4, 7, 3, 6, 8, 2]
# [4, 6, 8, 5, 1, 6, 7, 2]
# [8, 3, 1, 6, 4, 6, 7, 5]
# [7, 5, 8, 1, 5, 4, 6, 3]
# [7, 1, 6, 2, 5, 8, 5, 3]
# [8, 3, 1, 7, 4, 2, 7, 5]
# [3, 1, 7, 5, 8, 2, 4, 7]
# [4, 2, 5, 8, 5, 7, 3, 1]
# [1, 7, 5, 8, 8, 4, 6, 3]
# [8, 5, 2, 4, 1, 3, 7, 6]
# [8, 2, 1, 2, 3, 7, 5, 3]
# [4, 7, 1, 8, 5, 2, 8, 3]
# [8, 4, 7, 5, 2, 1, 6, 8]
# [6, 3, 1, 8, 5, 8, 2, 7]
# [3, 8, 7, 4, 1, 5, 3, 6]
# [6, 3, 8, 2, 5, 5, 1, 4]
# [5, 7, 1, 6, 8, 2, 1, 3]
# [8, 4, 6, 3, 5, 2, 7, 8]
# [7, 8, 2, 5, 6, 1, 4, 3]
# [8, 5, 7, 2, 6, 3, 1, 4]
# [5, 1, 6, 4, 8, 4, 3, 2]
# [8, 5, 7, 4, 1, 3, 6, 2]
# [8, 4, 1, 3, 6, 2, 7, 5]
# [3, 1, 6, 4, 8, 7, 5, 2]
# [8, 5, 4, 1, 7, 6, 2, 7]
# [8, 6, 1, 2, 4, 7, 3, 5]
# [3, 8, 6, 2, 4, 1, 7, 5]
# [8, 5, 2, 7, 1, 4, 3, 2]
# [8, 5, 3, 1, 2, 4, 6, 2]
# [8, 5, 7, 2, 4, 3, 1, 4]
# [4, 8, 1, 7, 2, 5, 8, 6]
# [8, 2, 5, 6, 7, 1, 3, 6]
# [2, 8, 7, 1, 3, 7, 6, 4]
# [5, 7, 2, 8, 3, 8, 1, 4]
# [8, 1, 4, 2, 5, 2, 6, 3]
# [5, 1, 8, 6, 7, 2, 4, 8]
# [8, 3, 6, 2, 7, 1, 6, 5]
# [4, 8, 5, 6, 2, 7, 3, 1]
# [8, 3, 6, 2, 7, 5, 4, 7]
# [7, 4, 1, 8, 7, 3, 6, 2]
# [8, 5, 2, 4, 3, 1, 6, 8]
# [3, 6, 8, 7, 2, 4, 8, 1]
# [5, 2, 8, 1, 4, 7, 3, 4]
# [8, 2, 3, 6, 2, 5, 1, 4]
# [7, 4, 1, 8, 4, 5, 2, 5]
# [7, 8, 2, 6, 1, 4, 4, 5]
# [7, 8, 1, 2, 4, 8, 3, 6]
# [8, 4, 6, 5, 2, 1, 7, 7]
# [7, 8, 1, 3, 7, 6, 4, 2]
# [8, 6, 1, 5, 2, 6, 3, 7]
# [8, 3, 7, 2, 4, 1, 3, 5]
# [8, 2, 6, 5, 1, 8, 1, 6]
# [2, 7, 8, 5, 7, 1, 4, 6]
# [8, 2, 4, 6, 2, 3, 5, 7]
# [8, 5, 2, 6, 3, 7, 7, 1]
# [8, 2, 7, 3, 6, 2, 5, 1]
# [8, 6, 2, 5, 4, 1, 7, 2]
# [8, 6, 3, 7, 4, 1, 2, 4]
# [6, 8, 5, 1, 4, 7, 5, 2]
# [3, 8, 1, 4, 6, 5, 2, 7]
# [8, 1, 5, 2, 3, 4, 7, 4]
# [1, 8, 8, 2, 4, 7, 5, 3]
# [8, 6, 1, 7, 5, 4, 2, 3]
# [5, 1, 4, 7, 3, 6, 8, 2]
# [6, 2, 8, 1, 4, 7, 5, 3]
# [6, 4, 1, 5, 8, 2, 3, 7]
# [6, 8, 7, 2, 5, 3, 1, 4]
# [8, 1, 6, 2, 7, 4, 8, 5]
# [4, 6, 1, 8, 5, 2, 5, 7]
# [8, 5, 7, 4, 1, 8, 6, 3]
# [5, 7, 8, 1, 6, 5, 3, 2]
# [8, 2, 2, 1, 5, 7, 7, 3]
# [6, 4, 2, 8, 5, 7, 3, 1]
# [4, 7, 8, 2, 6, 1, 3, 5]
# [8, 3, 7, 4, 2, 1, 6, 2]
# [8, 1, 2, 5, 7, 1, 6, 4]
# [8, 5, 2, 6, 4, 7, 7, 5]
# [8, 5, 7, 1, 3, 6, 2, 4]
# [2, 7, 5, 3, 1, 8, 4, 8]
# [8, 5, 4, 1, 3, 7, 7, 2]
# [5, 8, 4, 7, 5, 2, 3, 1]
# [7, 8, 6, 2, 4, 1, 3, 5]
# [8, 1, 5, 7, 2, 6, 1, 7]
# [8, 2, 3, 1, 6, 4, 2, 7]
# [6, 1, 5, 2, 8, 3, 6, 4]
# [2, 4, 7, 3, 8, 3, 5, 1]
# [8, 3, 6, 4, 2, 3, 1, 7]
# [8, 4, 2, 5, 6, 1, 3, 4]
# [8, 7, 1, 4, 2, 5, 6, 3]
# [8, 5, 3, 1, 4, 2, 5, 6]
# [6, 4, 8, 1, 3, 7, 6, 5]
# [8, 7, 2, 6, 3, 1, 7, 4]
# [5, 2, 8, 1, 3, 2, 6, 4]
# [8, 1, 7, 5, 6, 2, 4, 1]
# [8, 2, 4, 5, 1, 3, 2, 7]
# [7, 1, 4, 8, 5, 3, 2, 6]
# [6, 8, 6, 2, 7, 5, 1, 2]
# [7, 8, 3, 6, 5, 4, 2, 1]
# [3, 6, 8, 5, 2, 7, 7, 4]
# [5, 8, 6, 3, 7, 2, 8, 4]
# [8, 4, 2, 5, 5, 7, 1, 3]
# [7, 2, 4, 6, 8, 2, 5, 1]
# [4, 2, 5, 8, 1, 3, 5, 6]
# [7, 3, 8, 6, 1, 5, 4, 8]
# [8, 7, 2, 6, 3, 1, 5, 4]
# [4, 8, 1, 6, 4, 2, 7, 5]
# [1, 5, 2, 6, 3, 7, 8, 4]
# [4, 6, 1, 5, 2, 8, 1, 3]
# [8, 6, 3, 8, 7, 1, 4, 2]
# [7, 1, 3, 5, 8, 6, 4, 2]
# [6, 8, 7, 2, 5, 3, 1, 4]
# [8, 3, 1, 6, 2, 5, 8, 4]
# [8, 1, 3, 8, 6, 4, 2, 5]
# [8, 1, 4, 2, 5, 3, 7, 6]
# [8, 3, 7, 4, 1, 5, 2, 6]
# [8, 2, 4, 6, 1, 3, 7, 6]
# [8, 2, 7, 3, 6, 5, 3, 1]
# [8, 7, 2, 6, 1, 6, 4, 5]
# [5, 2, 8, 6, 3, 1, 4, 2]
# [3, 1, 6, 8, 5, 2, 3, 2]
# [8, 5, 7, 6, 4, 8, 2, 1]
# [3, 6, 8, 2, 4, 1, 5, 7]
# [8, 1, 2, 7, 6, 3, 4, 7]
# [5, 8, 1, 3, 6, 4, 1, 8]
# [8, 2, 6, 3, 7, 5, 1, 4]
# [8, 5, 2, 4, 7, 4, 1, 8]
# [2, 6, 8, 3, 8, 4, 7, 1]
# [8, 2, 7, 5, 6, 1, 5, 4]
# [6, 8, 1, 4, 5, 7, 3, 8]
# [6, 1, 5, 2, 8, 7, 4, 4]
# [8, 3, 5, 7, 2, 6, 1, 4]
# [8, 4, 8, 1, 7, 2, 3, 4]
# [4, 8, 3, 5, 6, 1, 6, 7]
# [8, 3, 4, 1, 5, 3, 6, 2]
# [6, 8, 5, 7, 8, 3, 2, 4]
# [8, 7, 1, 4, 2, 8, 3, 6]
# [2, 8, 6, 7, 4, 6, 3, 5]
# [8, 2, 6, 3, 1, 7, 5, 8]
# [3, 6, 4, 8, 1, 5, 2, 8]
# [8, 3, 4, 2, 7, 1, 3, 5]
# [4, 8, 6, 3, 1, 2, 3, 5]
# [2, 4, 8, 7, 3, 6, 1, 7]
# [4, 8, 1, 6, 7, 4, 2, 1]
# [8, 3, 7, 2, 4, 1, 5, 3]
# [1, 8, 4, 7, 3, 4, 6, 2]
# [7, 5, 1, 8, 1, 3, 6, 2]
# [8, 3, 4, 7, 1, 6, 5, 2]
# [8, 2, 7, 3, 4, 8, 5, 4]
# [8, 7, 1, 3, 6, 5, 4, 2]
# [8, 8, 4, 2, 7, 6, 1, 5]
# [6, 8, 5, 7, 1, 3, 2, 1]
# [7, 4, 8, 5, 2, 8, 3, 1]
# [7, 5, 1, 8, 4, 3, 7, 2]
# [8, 2, 4, 7, 1, 3, 5, 6]
# [5, 7, 8, 3, 2, 4, 1, 4]
# [8, 6, 3, 5, 7, 4, 3, 1]
# [3, 8, 4, 7, 1, 6, 3, 1]
# [1, 7, 8, 2, 1, 5, 6, 4]
# [7, 5, 3, 1, 6, 8, 8, 2]
# [8, 1, 5, 7, 2, 6, 1, 7]
# [2, 8, 3, 3, 7, 4, 1, 5]
# [8, 7, 3, 6, 2, 5, 1, 4]
# [2, 8, 8, 4, 7, 1, 3, 5]
# [8, 7, 1, 3, 5, 2, 4, 1]
# [8, 1, 8, 6, 3, 7, 2, 4]
# [8, 6, 7, 2, 3, 1, 7, 5]
# [3, 8, 7, 2, 5, 8, 1, 4]
# [5, 7, 1, 6, 8, 2, 7, 3]
# [8, 7, 2, 3, 6, 1, 2, 5]
# [6, 8, 5, 1, 7, 4, 2, 3]
# [6, 8, 2, 5, 7, 4, 1, 3]
# [8, 5, 1, 2, 4, 7, 1, 3]
# [8, 7, 3, 1, 6, 2, 5, 3]
# [3, 7, 8, 4, 6, 1, 5, 2]
# [3, 8, 7, 1, 4, 5, 2, 6]
# [5, 3, 8, 7, 4, 6, 1, 3]
# [8, 3, 1, 7, 4, 6, 6, 2]
# [8, 2, 5, 3, 7, 4, 3, 4]
# [8, 2, 7, 5, 3, 1, 4, 7]
# [2, 8, 3, 7, 4, 1, 2, 5]
# [6, 1, 7, 2, 8, 3, 2, 4]
# [8, 4, 1, 5, 7, 2, 8, 3]
# [8, 6, 2, 7, 4, 3, 6, 1]
# [8, 2, 6, 7, 3, 1, 8, 4]
# [6, 8, 3, 1, 4, 5, 2, 5]
# [8, 3, 7, 4, 1, 5, 7, 6]
# [4, 8, 3, 2, 6, 4, 7, 1]
# [5, 7, 1, 3, 8, 2, 1, 6]
# [2, 8, 5, 3, 4, 6, 7, 1]
# [2, 4, 7, 8, 3, 6, 7, 1]
# [4, 6, 1, 5, 2, 8, 7, 3]
# [4, 1, 8, 7, 5, 2, 7, 6]
# [8, 1, 5, 7, 2, 4, 5, 3]
# [3, 1, 6, 8, 5, 2, 2, 7]
# [8, 1, 3, 6, 8, 7, 4, 5]
# [7, 2, 4, 8, 1, 3, 6, 1]
# [8, 5, 2, 6, 3, 7, 5, 4]
# [7, 1, 4, 2, 8, 6, 3, 5]
# [3, 8, 2, 7, 5, 1, 2, 6]
# [8, 6, 2, 5, 3, 1, 4, 7]
# [3, 8, 6, 2, 1, 4, 7, 5]
# [4, 7, 8, 2, 6, 1, 3, 5]
# [8, 5, 3, 8, 6, 4, 1, 7]
# [8, 2, 6, 1, 3, 5, 8, 4]
# [4, 1, 3, 8, 6, 1, 5, 2]
# [5, 8, 1, 4, 7, 3, 6, 8]
# [8, 6, 3, 7, 1, 4, 2, 5]
# [4, 8, 6, 5, 7, 3, 1, 8]
# [8, 2, 5, 1, 6, 7, 3, 7]
# [6, 8, 1, 3, 4, 7, 8, 2]
# [6, 1, 8, 5, 7, 2, 4, 1]
# [8, 1, 6, 2, 5, 1, 4, 3]
# [8, 3, 5, 7, 2, 4, 6, 1]
# [4, 8, 3, 5, 3, 1, 7, 2]
# [7, 4, 2, 8, 4, 1, 3, 6]
# [1, 7, 8, 2, 6, 5, 3, 4]
# [7, 8, 3, 6, 4, 5, 2, 6]
# [5, 3, 1, 7, 8, 2, 8, 4]
# [8, 5, 1, 4, 2, 3, 1, 7]
# [8, 1, 6, 4, 2, 7, 5, 3]
# [4, 8, 1, 5, 7, 2, 4, 3]
# [5, 8, 1, 5, 2, 7, 2, 4]
# [8, 5, 2, 4, 1, 6, 2, 3]
# [8, 2, 5, 1, 4, 2, 3, 6]
# [4, 7, 1, 3, 8, 4, 6, 2]
# [5, 7, 4, 1, 8, 6, 1, 3]
# [8, 5, 2, 6, 1, 4, 7, 3]
# [6, 1, 8, 5, 7, 4, 5, 2]
# [4, 2, 5, 8, 6, 4, 3, 1]
# [5, 8, 7, 6, 2, 7, 1, 6]
# [3, 8, 2, 7, 5, 1, 4, 6]
# [8, 3, 2, 6, 7, 1, 8, 4]
# [1, 5, 7, 2, 8, 3, 6, 4]
# [2, 4, 7, 8, 4, 3, 1, 6]
# [6, 3, 1, 4, 8, 5, 2, 6]
# [4, 8, 1, 3, 6, 5, 2, 7]
# [2, 8, 6, 3, 1, 2, 5, 7]
# [8, 6, 7, 3, 1, 4, 2, 5]
# [5, 2, 8, 3, 4, 1, 6, 7]
# [8, 2, 7, 3, 1, 6, 4, 6]
# [4, 2, 7, 8, 1, 3, 4, 6]
# [8, 2, 4, 2, 3, 6, 7, 1]
# [8, 7, 3, 1, 5, 2, 2, 6]
# [4, 8, 3, 5, 7, 1, 8, 6]
# [4, 8, 7, 3, 8, 6, 2, 1]
# [5, 3, 8, 6, 2, 4, 7, 1]
# [8, 4, 5, 2, 4, 6, 1, 7]
# [2, 7, 1, 3, 5, 8, 1, 4]
# [2, 7, 5, 3, 1, 8, 4, 6]
# [8, 3, 2, 8, 7, 1, 6, 2]
# [8, 2, 5, 7, 3, 1, 3, 2]
# [8, 1, 3, 7, 2, 1, 5, 2]
# [8, 4, 7, 5, 2, 6, 1, 3]
# [1, 6, 8, 3, 8, 4, 2, 2]
# [7, 3, 6, 8, 1, 7, 4, 2]
# [8, 4, 6, 2, 3, 7, 1, 8]
# [8, 8, 3, 7, 2, 4, 6, 1]
# [6, 8, 3, 4, 3, 2, 6, 8]
# [3, 6, 8, 1, 6, 4, 7, 2]
# [2, 7, 3, 8, 4, 1, 4, 6]
# [3, 7, 4, 1, 8, 6, 5, 2]
# [4, 8, 8, 3, 6, 2, 5, 7]
# [4, 8, 7, 2, 6, 1, 3, 5]
# [8, 2, 6, 1, 7, 5, 4, 8]
# [8, 6, 8, 1, 2, 3, 7, 7]
# [8, 1, 4, 6, 7, 2, 7, 3]
# [3, 1, 4, 8, 3, 6, 2, 6]
# [8, 4, 1, 7, 2, 6, 3, 5]
# [8, 3, 1, 7, 2, 6, 1, 8]
# [4, 6, 8, 3, 1, 3, 5, 2]
# [7, 5, 8, 6, 1, 4, 2, 3]
# [8, 5, 2, 7, 1, 6, 4, 3]
# [8, 8, 5, 2, 4, 1, 2, 6]
# [3, 6, 2, 7, 1, 4, 8, 5]
# [8, 8, 4, 2, 7, 5, 1, 4]
# [8, 7, 3, 4, 2, 5, 1, 6]
# [2, 7, 8, 3, 5, 7, 1, 4]
# [8, 3, 6, 1, 1, 4, 7, 1]
# [5, 3, 1, 8, 2, 6, 3, 7]
# [8, 5, 7, 1, 3, 5, 4, 2]
# [2, 8, 5, 4, 1, 3, 6, 7]
# [2, 8, 1, 4, 4, 6, 3, 5]
# [2, 8, 1, 4, 3, 5, 8, 7]
# [8, 4, 1, 3, 5, 2, 6, 1]
# [2, 8, 3, 4, 3, 5, 1, 6]
# [5, 2, 8, 6, 7, 4, 3, 1]
# [8, 5, 5, 1, 4, 7, 5, 3]
# [7, 2, 4, 6, 1, 8, 5, 3]
# [5, 8, 4, 1, 7, 2, 5, 6]
# [1, 8, 6, 3, 7, 4, 1, 2]
# [3, 8, 6, 4, 1, 6, 8, 5]
# [3, 8, 4, 8, 5, 2, 6, 1]
# [4, 8, 6, 6, 1, 3, 7, 2]
# [2, 8, 7, 1, 3, 8, 6, 4]
# [6, 8, 7, 4, 3, 2, 8, 1]
# [5, 8, 4, 6, 2, 4, 7, 4]
# [8, 5, 7, 4, 1, 3, 6, 5]
# [8, 7, 1, 6, 2, 3, 8, 7]
# [8, 3, 6, 5, 2, 8, 1, 4]
# [7, 3, 8, 7, 5, 1, 6, 2]
# [4, 6, 8, 5, 1, 8, 7, 2]
# [1, 6, 8, 5, 2, 4, 8, 6]
# [2, 4, 6, 8, 3, 1, 7, 1]
# [8, 4, 7, 1, 3, 6, 5, 2]
# [8, 6, 4, 1, 5, 2, 7, 3]
# [5, 8, 1, 4, 6, 7, 2, 5]
# [8, 6, 3, 7, 2, 4, 5, 1]
# [8, 6, 4, 7, 1, 3, 2, 5]
# [4, 7, 8, 3, 6, 1, 2, 5]
# [8, 2, 3, 7, 2, 8, 1, 4]
# [4, 7, 8, 2, 6, 5, 3, 4]
# [5, 8, 1, 7, 8, 3, 6, 4]
# [6, 8, 5, 1, 3, 4, 7, 2]
# [8, 2, 4, 1, 8, 5, 3, 6]
# [8, 1, 4, 6, 1, 2, 7, 3]
# [8, 5, 3, 1, 7, 4, 6, 2]
# [7, 5, 2, 8, 6, 2, 4, 1]
# [8, 3, 7, 2, 8, 6, 4, 5]
# [3, 6, 8, 3, 4, 1, 7, 2]
# [8, 6, 4, 7, 1, 3, 2, 5]
# [8, 6, 3, 1, 2, 5, 3, 4]
# [8, 2, 4, 5, 7, 1, 3, 5]
# [6, 8, 3, 1, 7, 4, 2, 5]
# [8, 3, 5, 7, 1, 2, 6, 2]
# [8, 3, 1, 6, 4, 2, 5, 8]
# [6, 1, 8, 5, 3, 8, 4, 2]
# [6, 4, 7, 1, 8, 2, 6, 3]
# [7, 8, 3, 4, 2, 1, 4, 6]
# [8, 3, 7, 6, 2, 5, 1, 6]
# [8, 2, 6, 1, 3, 8, 5, 7]
# [8, 2, 7, 1, 3, 5, 2, 4]
# [4, 1, 8, 2, 5, 1, 4, 3]
# [8, 4, 6, 1, 5, 7, 6, 3]
# [7, 5, 8, 2, 3, 6, 2, 1]
# [7, 4, 8, 5, 3, 1, 6, 2]
# [4, 2, 8, 6, 3, 1, 8, 5]
# [8, 5, 2, 7, 1, 3, 4, 6]
# [6, 8, 5, 1, 3, 7, 8, 4]
# [7, 8, 6, 3, 1, 4, 7, 2]
# [6, 1, 8, 7, 1, 3, 5, 2]
# [5, 3, 8, 7, 2, 4, 1, 5]
# [8, 1, 5, 7, 2, 4, 3, 5]
# [1, 8, 7, 5, 4, 2, 5, 6]
# [4, 6, 1, 8, 7, 3, 6, 2]
# [3, 7, 2, 4, 8, 1, 3, 5]
# [4, 7, 1, 8, 5, 2, 6, 3]
# [8, 3, 5, 7, 1, 4, 2, 6]
# [2, 6, 1, 3, 5, 8, 8, 4]
# [2, 5, 8, 4, 1, 3, 8, 6]
# [6, 8, 2, 5, 1, 3, 8, 1]
# [3, 8, 2, 5, 3, 4, 1, 6]
# [4, 7, 8, 3, 5, 2, 1, 6]
# [5, 7, 4, 8, 3, 6, 1, 3]
# [7, 8, 4, 2, 5, 6, 3, 1]
# [8, 5, 2, 4, 7, 5, 3, 1]
# [2, 6, 8, 7, 5, 3, 1, 7]
# [1, 7, 8, 2, 2, 5, 8, 4]
# [4, 7, 8, 3, 1, 6, 8, 2]
# [2, 4, 6, 8, 3, 1, 4, 7]
# [6, 2, 8, 5, 1, 4, 6, 7]
# [8, 7, 5, 3, 1, 6, 4, 2]
# [6, 3, 8, 3, 1, 2, 4, 5]
# [2, 7, 5, 8, 1, 4, 6, 4]
# [8, 5, 3, 4, 1, 7, 5, 2]
# [7, 4, 6, 8, 2, 5, 3, 8]
# [8, 7, 1, 4, 2, 5, 3, 6]
# [8, 4, 7, 1, 2, 5, 7, 3]
# [8, 5, 6, 1, 3, 7, 4, 2]
# [8, 1, 4, 5, 3, 4, 7, 2]
# [3, 8, 6, 4, 6, 1, 3, 7]
# [8, 3, 5, 1, 4, 7, 8, 6]
# [8, 7, 5, 3, 1, 4, 1, 2]
# [8, 4, 3, 5, 7, 1, 6, 7]
# [3, 8, 7, 1, 5, 7, 2, 8]
# [8, 2, 5, 3, 8, 6, 2, 1]
# [8, 4, 7, 5, 2, 6, 8, 1]
# [8, 6, 1, 2, 7, 1, 3, 5]
# [4, 8, 6, 3, 1, 6, 2, 5]
# [8, 2, 7, 3, 8, 4, 1, 1]
# [2, 8, 3, 6, 6, 1, 4, 4]
# [8, 7, 1, 3, 8, 6, 4, 2]
# [8, 3, 1, 7, 5, 4, 2, 1]
# [4, 7, 8, 3, 6, 8, 1, 2]
# [8, 4, 2, 7, 3, 6, 8, 1]
# [8, 1, 6, 5, 3, 7, 4, 2]
# [8, 1, 5, 8, 2, 4, 1, 3]
# [8, 5, 3, 6, 7, 3, 1, 4]
# [3, 5, 8, 1, 4, 3, 7, 2]
# [8, 3, 7, 2, 4, 1, 5, 6]
# [8, 4, 1, 8, 6, 3, 2, 7]
# [4, 1, 8, 5, 2, 7, 3, 4]
# [8, 3, 5, 2, 5, 6, 4, 1]
# [8, 5, 2, 6, 3, 7, 4, 1]
# [5, 1, 6, 4, 2, 8, 5, 3]
# [1, 6, 8, 7, 4, 3, 5, 2]
# [4, 8, 5, 6, 2, 7, 1, 3]
# [7, 4, 6, 8, 2, 5, 1, 8]
# [3, 7, 4, 8, 3, 5, 1, 6]
# [5, 8, 2, 4, 8, 5, 3, 1]
# [6, 4, 2, 7, 8, 3, 1, 5]
# [2, 8, 5, 1, 7, 4, 6, 8]
# [2, 8, 6, 1, 7, 5, 3, 8]
# [4, 1, 8, 5, 2, 7, 3, 6]
# [7, 5, 8, 2, 3, 6, 5, 1]
# [6, 8, 7, 1, 3, 8, 2, 4]
# [8, 6, 2, 3, 1, 7, 3, 2]
# [7, 2, 6, 3, 1, 8, 3, 5]
# [6, 4, 7, 8, 3, 2, 5, 1]
# [5, 2, 8, 1, 7, 4, 5, 3]
# [3, 8, 4, 5, 1, 6, 2, 7]
# [2, 5, 8, 6, 3, 1, 4, 7]
# [8, 1, 6, 7, 5, 4, 1, 3]
# [6, 2, 7, 8, 7, 5, 1, 4]
# [1, 8, 4, 6, 8, 2, 5, 7]
# [5, 3, 8, 6, 7, 1, 4, 1]
# [8, 4, 7, 5, 2, 1, 6, 6]
# [4, 1, 3, 8, 7, 2, 4, 5]
# [8, 1, 5, 2, 6, 2, 4, 3]
# [8, 5, 3, 2, 4, 7, 1, 6]
# [8, 8, 5, 2, 1, 7, 4, 6]
# [4, 8, 3, 6, 7, 1, 4, 5]
# [8, 6, 3, 1, 4, 6, 5, 2]
# [7, 8, 3, 6, 2, 5, 4, 1]
# [2, 5, 8, 6, 2, 3, 1, 7]
# [8, 6, 1, 5, 4, 3, 5, 2]
# [7, 1, 8, 5, 2, 4, 5, 3]
# [8, 6, 1, 3, 7, 2, 3, 5]
# [5, 8, 2, 5, 7, 3, 1, 6]
# [8, 6, 2, 7, 1, 3, 5, 4]
# [5, 2, 4, 8, 7, 3, 1, 2]
# [6, 8, 3, 1, 4, 2, 5, 1]
# [3, 8, 7, 1, 4, 5, 2, 6]
# [8, 5, 1, 6, 2, 5, 4, 7]
# [8, 7, 3, 6, 2, 4, 1, 1]
# [2, 8, 6, 1, 3, 7, 4, 5]
# [8, 6, 3, 2, 4, 1, 5, 7]
# [8, 5, 1, 4, 7, 3, 6, 2]
# [2, 8, 3, 4, 7, 6, 1, 5]
# [7, 4, 1, 8, 8, 3, 6, 2]
# [7, 5, 8, 2, 6, 2, 8, 4]
# [8, 3, 8, 2, 6, 4, 1, 7]
# [8, 1, 6, 4, 1, 3, 5, 2]
# [8, 7, 3, 1, 6, 4, 5, 8]
# [8, 7, 2, 6, 3, 1, 4, 2]
# [5, 8, 2, 6, 1, 7, 8, 4]
# [2, 8, 7, 1, 4, 8, 5, 8]
# [8, 3, 1, 7, 2, 5, 6, 4]
# [3, 8, 4, 3, 1, 6, 2, 7]
# [3, 6, 2, 7, 1, 4, 8, 8]
# [4, 8, 1, 5, 3, 6, 1, 5]
# [3, 6, 8, 4, 1, 6, 2, 7]
# [3, 8, 4, 1, 8, 6, 7, 2]
# [7, 8, 2, 6, 4, 1, 2, 5]
# [2, 7, 8, 3, 5, 7, 1, 4]
# [2, 4, 8, 7, 5, 3, 1, 6]
# [3, 8, 4, 1, 3, 6, 2, 1]
# [1, 8, 2, 7, 3, 6, 4, 5]
# [8, 6, 1, 3, 5, 7, 2, 4]
# [2, 7, 1, 8, 1, 6, 3, 7]
# [8, 4, 1, 7, 6, 2, 7, 2]
# [6, 3, 1, 8, 5, 2, 8, 7]
# [4, 7, 8, 2, 5, 1, 6, 3]
# [3, 5, 8, 8, 1, 4, 2, 7]
# [4, 8, 8, 6, 3, 1, 7, 5]
# [8, 7, 2, 4, 6, 1, 3, 5]
# [4, 1, 5, 8, 2, 7, 5, 3]
# [6, 8, 1, 7, 4, 3, 7, 2]
# [5, 1, 8, 6, 4, 2, 5, 7]
# [8, 7, 2, 6, 3, 1, 8, 4]
# [6, 2, 7, 8, 4, 6, 1, 3]
# [8, 3, 7, 2, 5, 1, 6, 4]
# [6, 8, 1, 7, 5, 3, 4, 3]
# [7, 8, 1, 3, 8, 5, 2, 4]
# [6, 4, 1, 8, 5, 2, 3, 8]
# [8, 3, 5, 2, 1, 6, 3, 7]
# [8, 4, 1, 5, 2, 6, 3, 7]
# [6, 1, 5, 2, 8, 3, 7, 4]
# ********************** Solutions **********************
# The number of solutions you wanted: 8
#
# Solution number 1: [8, 2, 5, 3, 1, 7, 4, 6]
#
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
#
#
# Solution number 2: [4, 7, 3, 8, 2, 5, 1, 6]
#
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
#
#
# Solution number 3: [8, 3, 1, 6, 2, 5, 7, 4]
#
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][ ][Q][ ][ ][ ][ ]
#
#
# Solution number 4: [8, 2, 4, 1, 7, 5, 3, 6]
#
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
#
#
# Solution number 5: [8, 4, 1, 3, 6, 2, 7, 5]
#
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
#
#
# Solution number 6: [3, 6, 2, 7, 1, 4, 8, 5]
#
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][ ][ ][ ][Q][ ][ ][ ]
#
#
# Solution number 7: [4, 7, 1, 8, 5, 2, 6, 3]
#
# [ ][ ][ ][Q][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][Q][ ][ ]
# [ ][ ][Q][ ][ ][ ][ ][ ]
#
#
# Solution number 8: [6, 1, 5, 2, 8, 3, 7, 4]
#
# [ ][ ][ ][ ][ ][Q][ ][ ]
# [Q][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][Q][ ][ ][ ]
# [ ][Q][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][Q]
# [ ][ ][Q][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][Q][ ]
# [ ][ ][ ][Q][ ][ ][ ][ ]
#
# *******************************************************
